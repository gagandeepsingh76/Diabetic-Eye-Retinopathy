# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/enhanced.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152 to InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
train_dir = "/content/dataset/enhanced/train"
val_dir = "/content/dataset/enhanced/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator


# === Data generators ===
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

# === Load image data ===
train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(299, 299),  # ✅ Required input size for InceptionV3
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(299, 299),  # ✅ Required input size for InceptionV3
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 712 images belonging to 2 classes.
# Found 848 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

# Load InceptionV3 as base model
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))  # 🔄 Updated input size

# Freeze initial layers
for layer in base_model.layers[:200]:  # 🔄 InceptionV3 has fewer layers than ResNet152
    layer.trainable = False

# Unfreeze later layers
for layer in base_model.layers[200:]:
    layer.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define optimizer
optimizer = SGD(learning_rate=0.01,momentum=0.9,nesterov=True)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# ✅ Updated input shape for InceptionV3
model.build((None, 299, 299, 3))

# ✅ Updated checkpoint filename to reflect InceptionV3
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_inceptionv3_model.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Train the model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=21,
    callbacks=[checkpoint, lr_scheduler]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4082 - loss: 1.8536
# Epoch 1: val_loss improved from inf to 5.29772, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 110s 3s/step - accuracy: 0.4135 - loss: 1.8399 - val_accuracy: 0.5767 - val_loss: 5.2977 - learning_rate: 0.0100
# Epoch 2/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 766ms/step - accuracy: 0.7585 - loss: 0.7631
# Epoch 2: val_loss improved from 5.29772 to 2.36727, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - accuracy: 0.7589 - loss: 0.7607 - val_accuracy: 0.4870 - val_loss: 2.3673 - learning_rate: 0.0100
# Epoch 3/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 990ms/step - accuracy: 0.8215 - loss: 0.4704
# Epoch 3: val_loss did not improve from 2.36727
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.8213 - loss: 0.4714 - val_accuracy: 0.6392 - val_loss: 2.3756 - learning_rate: 0.0100
# Epoch 4/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 825ms/step - accuracy: 0.8499 - loss: 0.3654
# Epoch 4: val_loss improved from 2.36727 to 0.74116, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8492 - loss: 0.3671 - val_accuracy: 0.7370 - val_loss: 0.7412 - learning_rate: 0.0100
# Epoch 5/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 924ms/step - accuracy: 0.8136 - loss: 0.4774
# Epoch 5: val_loss improved from 0.74116 to 0.70148, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.8140 - loss: 0.4752 - val_accuracy: 0.6816 - val_loss: 0.7015 - learning_rate: 0.0100
# Epoch 6/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 882ms/step - accuracy: 0.8686 - loss: 0.3322
# Epoch 6: val_loss improved from 0.70148 to 0.58033, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 63s 3s/step - accuracy: 0.8687 - loss: 0.3315 - val_accuracy: 0.7417 - val_loss: 0.5803 - learning_rate: 0.0100
# Epoch 7/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 916ms/step - accuracy: 0.9024 - loss: 0.2676
# Epoch 7: val_loss did not improve from 0.58033
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9012 - loss: 0.2703 - val_accuracy: 0.6321 - val_loss: 0.8410 - learning_rate: 0.0100
# Epoch 8/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 763ms/step - accuracy: 0.8754 - loss: 0.2788
# Epoch 8: val_loss did not improve from 0.58033
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0029999999329447745.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.8753 - loss: 0.2797 - val_accuracy: 0.7087 - val_loss: 0.5999 - learning_rate: 0.0100
# Epoch 9/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 770ms/step - accuracy: 0.8614 - loss: 0.3539
# Epoch 9: val_loss improved from 0.58033 to 0.54451, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8615 - loss: 0.3533 - val_accuracy: 0.7217 - val_loss: 0.5445 - learning_rate: 0.0030
# Epoch 10/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 914ms/step - accuracy: 0.8931 - loss: 0.2557
# Epoch 10: val_loss improved from 0.54451 to 0.46949, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.8927 - loss: 0.2566 - val_accuracy: 0.7559 - val_loss: 0.4695 - learning_rate: 0.0030
# Epoch 11/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 876ms/step - accuracy: 0.9157 - loss: 0.2469
# Epoch 11: val_loss improved from 0.46949 to 0.43984, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9160 - loss: 0.2461 - val_accuracy: 0.7807 - val_loss: 0.4398 - learning_rate: 0.0030
# Epoch 12/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 986ms/step - accuracy: 0.9107 - loss: 0.2372
# Epoch 12: val_loss improved from 0.43984 to 0.42250, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9109 - loss: 0.2364 - val_accuracy: 0.7866 - val_loss: 0.4225 - learning_rate: 0.0030
# Epoch 13/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 919ms/step - accuracy: 0.9139 - loss: 0.2137
# Epoch 13: val_loss improved from 0.42250 to 0.40143, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9142 - loss: 0.2131 - val_accuracy: 0.8066 - val_loss: 0.4014 - learning_rate: 0.0030
# Epoch 14/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 931ms/step - accuracy: 0.9078 - loss: 0.2747
# Epoch 14: val_loss did not improve from 0.40143
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 62s 3s/step - accuracy: 0.9080 - loss: 0.2725 - val_accuracy: 0.8019 - val_loss: 0.4245 - learning_rate: 0.0030
# Epoch 15/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 827ms/step - accuracy: 0.9298 - loss: 0.1787
# Epoch 15: val_loss improved from 0.40143 to 0.37461, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9298 - loss: 0.1783 - val_accuracy: 0.8160 - val_loss: 0.3746 - learning_rate: 0.0030
# Epoch 16/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 919ms/step - accuracy: 0.9254 - loss: 0.1871
# Epoch 16: val_loss improved from 0.37461 to 0.32265, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9256 - loss: 0.1869 - val_accuracy: 0.8455 - val_loss: 0.3227 - learning_rate: 0.0030
# Epoch 17/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 768ms/step - accuracy: 0.9322 - loss: 0.1656
# Epoch 17: val_loss did not improve from 0.32265
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.9321 - loss: 0.1657 - val_accuracy: 0.8373 - val_loss: 0.3780 - learning_rate: 0.0030
# Epoch 18/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - accuracy: 0.9468 - loss: 0.1432
# Epoch 18: val_loss did not improve from 0.32265
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0009000000078231095.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9465 - loss: 0.1440 - val_accuracy: 0.8196 - val_loss: 0.3813 - learning_rate: 0.0030
# Epoch 19/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 762ms/step - accuracy: 0.9328 - loss: 0.1730
# Epoch 19: val_loss did not improve from 0.32265
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9331 - loss: 0.1726 - val_accuracy: 0.8125 - val_loss: 0.4333 - learning_rate: 9.0000e-04
# Epoch 20/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 770ms/step - accuracy: 0.9419 - loss: 0.1550
# Epoch 20: val_loss did not improve from 0.32265
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00026999999536201356.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9419 - loss: 0.1548 - val_accuracy: 0.8491 - val_loss: 0.3545 - learning_rate: 9.0000e-04
# Epoch 21/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 764ms/step - accuracy: 0.9341 - loss: 0.1468
# Epoch 21: val_loss did not improve from 0.32265
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9342 - loss: 0.1469 - val_accuracy: 0.8314 - val_loss: 0.4017 - learning_rate: 2.7000e-04

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained ResNet152 model ===
model_path = "/content/drive/MyDrive/best_inceptionv3_model.keras"
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_inceptionv3_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 34s 978ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1]
# Valid labels: [0, 1]
# Target names: ['abnormal', 'normal']
#
# Predicted sample count per class:
# abnormal: 280
# normal: 568
#
# ✅ Overall Validation Accuracy: 84.67%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     abnormal       0.89      0.72      0.79       348
#       normal       0.83      0.94      0.88       500
#
#     accuracy                           0.85       848
#    macro avg       0.86      0.83      0.84       848
# weighted avg       0.85      0.85      0.84       848

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
