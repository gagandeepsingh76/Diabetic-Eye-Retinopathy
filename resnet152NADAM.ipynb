# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/gagandeep.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
train_dir = "/content/dataset/gagandeep/train"
val_dir = "/content/dataset/gagandeep/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest')

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 712 images belonging to 2 classes.
# Found 848 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

base_model = ResNet152(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze initial layers
for layer in base_model.layers[:600]:
    layer.trainable = False

# Unfreeze later layers for fine-tuning
for layer in base_model.layers[600:]:
    layer.trainable = True

x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define optimizer
optimizer = Nadam(learning_rate=1e-4)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.build((None, 224, 224, 3))

# Callbacks — No EarlyStopping used
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_resnet152_model.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Fit the model for all 51 epochs
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=51,
    callbacks=[checkpoint, lr_scheduler]  # early_stop removed
)
# Out:
# Epoch 1/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.1877 - loss: 2.1791
# Epoch 1: val_loss improved from inf to 1.91939, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.1886 - loss: 2.1765 - val_accuracy: 0.0000e+00 - val_loss: 1.9194 - learning_rate: 1.0000e-04
# Epoch 2/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.2328 - loss: 2.0304
# Epoch 2: val_loss improved from 1.91939 to 1.89025, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.2338 - loss: 2.0295 - val_accuracy: 0.0000e+00 - val_loss: 1.8903 - learning_rate: 1.0000e-04
# Epoch 3/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.2595 - loss: 1.9610
# Epoch 3: val_loss improved from 1.89025 to 1.80385, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.2603 - loss: 1.9583 - val_accuracy: 0.0000e+00 - val_loss: 1.8039 - learning_rate: 1.0000e-04
# Epoch 4/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.2948 - loss: 1.8826
# Epoch 4: val_loss improved from 1.80385 to 1.72544, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.2956 - loss: 1.8812 - val_accuracy: 0.0000e+00 - val_loss: 1.7254 - learning_rate: 1.0000e-04
# Epoch 5/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.3249 - loss: 1.7949
# Epoch 5: val_loss improved from 1.72544 to 1.65374, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.3254 - loss: 1.7941 - val_accuracy: 0.0000e+00 - val_loss: 1.6537 - learning_rate: 1.0000e-04
# Epoch 6/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.3519 - loss: 1.8025
# Epoch 6: val_loss improved from 1.65374 to 1.61046, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.3521 - loss: 1.7989 - val_accuracy: 0.0012 - val_loss: 1.6105 - learning_rate: 1.0000e-04
# Epoch 7/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.3890 - loss: 1.7287
# Epoch 7: val_loss improved from 1.61046 to 1.53794, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.3891 - loss: 1.7292 - val_accuracy: 0.0047 - val_loss: 1.5379 - learning_rate: 1.0000e-04
# Epoch 8/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.3751 - loss: 1.6960
# Epoch 8: val_loss improved from 1.53794 to 1.50060, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.3753 - loss: 1.6964 - val_accuracy: 0.2311 - val_loss: 1.5006 - learning_rate: 1.0000e-04
# Epoch 9/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.4109 - loss: 1.6902
# Epoch 9: val_loss improved from 1.50060 to 1.46869, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.4110 - loss: 1.6867 - val_accuracy: 0.3797 - val_loss: 1.4687 - learning_rate: 1.0000e-04
# Epoch 10/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.3937 - loss: 1.6699
# Epoch 10: val_loss improved from 1.46869 to 1.40073, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.3943 - loss: 1.6689 - val_accuracy: 0.5271 - val_loss: 1.4007 - learning_rate: 1.0000e-04
# Epoch 11/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.4430 - loss: 1.5702
# Epoch 11: val_loss improved from 1.40073 to 1.36805, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.4435 - loss: 1.5695 - val_accuracy: 0.5590 - val_loss: 1.3680 - learning_rate: 1.0000e-04
# Epoch 12/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.4812 - loss: 1.4919
# Epoch 12: val_loss improved from 1.36805 to 1.34589, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.4813 - loss: 1.4917 - val_accuracy: 0.5637 - val_loss: 1.3459 - learning_rate: 1.0000e-04
# Epoch 13/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.4711 - loss: 1.5521
# Epoch 13: val_loss improved from 1.34589 to 1.29313, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.4712 - loss: 1.5504 - val_accuracy: 0.5884 - val_loss: 1.2931 - learning_rate: 1.0000e-04
# Epoch 14/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.4691 - loss: 1.5229
# Epoch 14: val_loss improved from 1.29313 to 1.24244, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.4694 - loss: 1.5215 - val_accuracy: 0.6061 - val_loss: 1.2424 - learning_rate: 1.0000e-04
# Epoch 15/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.4290 - loss: 1.5488
# Epoch 15: val_loss improved from 1.24244 to 1.21993, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.4300 - loss: 1.5483 - val_accuracy: 0.5991 - val_loss: 1.2199 - learning_rate: 1.0000e-04
# Epoch 16/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.5241 - loss: 1.4044
# Epoch 16: val_loss improved from 1.21993 to 1.18889, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.5228 - loss: 1.4065 - val_accuracy: 0.6156 - val_loss: 1.1889 - learning_rate: 1.0000e-04
# Epoch 17/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 518ms/step - accuracy: 0.4805 - loss: 1.4203
# Epoch 17: val_loss improved from 1.18889 to 1.14636, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.4802 - loss: 1.4211 - val_accuracy: 0.6262 - val_loss: 1.1464 - learning_rate: 1.0000e-04
# Epoch 18/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.5190 - loss: 1.3832
# Epoch 18: val_loss improved from 1.14636 to 1.11034, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.5195 - loss: 1.3811 - val_accuracy: 0.6297 - val_loss: 1.1103 - learning_rate: 1.0000e-04
# Epoch 19/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.5292 - loss: 1.3619
# Epoch 19: val_loss improved from 1.11034 to 1.09711, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.5295 - loss: 1.3622 - val_accuracy: 0.6356 - val_loss: 1.0971 - learning_rate: 1.0000e-04
# Epoch 20/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.5451 - loss: 1.2548
# Epoch 20: val_loss improved from 1.09711 to 1.08337, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.5447 - loss: 1.2583 - val_accuracy: 0.6733 - val_loss: 1.0834 - learning_rate: 1.0000e-04
# Epoch 21/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.5349 - loss: 1.3562
# Epoch 21: val_loss improved from 1.08337 to 1.05773, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.5350 - loss: 1.3549 - val_accuracy: 0.6757 - val_loss: 1.0577 - learning_rate: 1.0000e-04
# Epoch 22/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.5792 - loss: 1.2881
# Epoch 22: val_loss improved from 1.05773 to 1.01212, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.5787 - loss: 1.2877 - val_accuracy: 0.7005 - val_loss: 1.0121 - learning_rate: 1.0000e-04
# Epoch 23/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.5404 - loss: 1.3627
# Epoch 23: val_loss did not improve from 1.01212
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.5409 - loss: 1.3615 - val_accuracy: 0.6910 - val_loss: 1.0137 - learning_rate: 1.0000e-04
# Epoch 24/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.5894 - loss: 1.2116
# Epoch 24: val_loss improved from 1.01212 to 0.99332, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.5886 - loss: 1.2136 - val_accuracy: 0.7111 - val_loss: 0.9933 - learning_rate: 1.0000e-04
# Epoch 25/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.5165 - loss: 1.3482
# Epoch 25: val_loss improved from 0.99332 to 0.98057, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.5167 - loss: 1.3482 - val_accuracy: 0.6934 - val_loss: 0.9806 - learning_rate: 1.0000e-04
# Epoch 26/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.5441 - loss: 1.2496
# Epoch 26: val_loss did not improve from 0.98057
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.5446 - loss: 1.2495 - val_accuracy: 0.6922 - val_loss: 0.9900 - learning_rate: 1.0000e-04
# Epoch 27/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.6265 - loss: 1.1128
# Epoch 27: val_loss improved from 0.98057 to 0.95475, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.6255 - loss: 1.1146 - val_accuracy: 0.7075 - val_loss: 0.9548 - learning_rate: 1.0000e-04
# Epoch 28/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.5976 - loss: 1.1930
# Epoch 28: val_loss improved from 0.95475 to 0.95372, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.5980 - loss: 1.1925 - val_accuracy: 0.7158 - val_loss: 0.9537 - learning_rate: 1.0000e-04
# Epoch 29/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.6128 - loss: 1.1474
# Epoch 29: val_loss improved from 0.95372 to 0.93488, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.6122 - loss: 1.1492 - val_accuracy: 0.7134 - val_loss: 0.9349 - learning_rate: 1.0000e-04
# Epoch 30/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.5902 - loss: 1.1475
# Epoch 30: val_loss improved from 0.93488 to 0.91955, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.5903 - loss: 1.1482 - val_accuracy: 0.7252 - val_loss: 0.9196 - learning_rate: 1.0000e-04
# Epoch 31/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.6164 - loss: 1.0751
# Epoch 31: val_loss did not improve from 0.91955
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.6164 - loss: 1.0753 - val_accuracy: 0.7264 - val_loss: 0.9256 - learning_rate: 1.0000e-04
# Epoch 32/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.5767 - loss: 1.2149
# Epoch 32: val_loss improved from 0.91955 to 0.89366, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.5776 - loss: 1.2132 - val_accuracy: 0.7323 - val_loss: 0.8937 - learning_rate: 1.0000e-04
# Epoch 33/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.6504 - loss: 1.0585
# Epoch 33: val_loss did not improve from 0.89366
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.6502 - loss: 1.0582 - val_accuracy: 0.7111 - val_loss: 0.9153 - learning_rate: 1.0000e-04
# Epoch 34/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.6115 - loss: 1.0981
# Epoch 34: val_loss did not improve from 0.89366
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.6124 - loss: 1.0966 - val_accuracy: 0.7193 - val_loss: 0.9271 - learning_rate: 1.0000e-04
# Epoch 35/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.6359 - loss: 1.0801
# Epoch 35: val_loss improved from 0.89366 to 0.86748, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.6357 - loss: 1.0802 - val_accuracy: 0.7370 - val_loss: 0.8675 - learning_rate: 3.0000e-05
# Epoch 36/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.6106 - loss: 1.1316
# Epoch 36: val_loss did not improve from 0.86748
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.6103 - loss: 1.1316 - val_accuracy: 0.7465 - val_loss: 0.8734 - learning_rate: 3.0000e-05
# Epoch 37/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.6139 - loss: 1.1219
# Epoch 37: val_loss improved from 0.86748 to 0.86483, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.6145 - loss: 1.1210 - val_accuracy: 0.7087 - val_loss: 0.8648 - learning_rate: 3.0000e-05
# Epoch 38/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.6290 - loss: 1.0637
# Epoch 38: val_loss improved from 0.86483 to 0.86457, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.6287 - loss: 1.0635 - val_accuracy: 0.7300 - val_loss: 0.8646 - learning_rate: 3.0000e-05
# Epoch 39/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.6565 - loss: 1.0925
# Epoch 39: val_loss did not improve from 0.86457
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.6550 - loss: 1.0936 - val_accuracy: 0.7252 - val_loss: 0.8930 - learning_rate: 3.0000e-05
# Epoch 40/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.6508 - loss: 0.9932
# Epoch 40: val_loss improved from 0.86457 to 0.85637, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6506 - loss: 0.9936 - val_accuracy: 0.7347 - val_loss: 0.8564 - learning_rate: 3.0000e-05
# Epoch 41/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.6354 - loss: 1.0974
# Epoch 41: val_loss improved from 0.85637 to 0.83243, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.6355 - loss: 1.0973 - val_accuracy: 0.7382 - val_loss: 0.8324 - learning_rate: 3.0000e-05
# Epoch 42/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 515ms/step - accuracy: 0.6598 - loss: 0.9685
# Epoch 42: val_loss did not improve from 0.83243
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.6601 - loss: 0.9686 - val_accuracy: 0.7394 - val_loss: 0.8402 - learning_rate: 3.0000e-05
# Epoch 43/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.6247 - loss: 1.0716
# Epoch 43: val_loss did not improve from 0.83243
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.6247 - loss: 1.0726 - val_accuracy: 0.7193 - val_loss: 0.8509 - learning_rate: 3.0000e-05
# Epoch 44/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.6442 - loss: 1.0311
# Epoch 44: val_loss did not improve from 0.83243
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.6439 - loss: 1.0334 - val_accuracy: 0.7288 - val_loss: 0.8665 - learning_rate: 9.0000e-06
# Epoch 45/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.6869 - loss: 0.9763
# Epoch 45: val_loss did not improve from 0.83243
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6865 - loss: 0.9758 - val_accuracy: 0.7288 - val_loss: 0.8559 - learning_rate: 9.0000e-06
# Epoch 46/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.6253 - loss: 1.0517
# Epoch 46: val_loss did not improve from 0.83243
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.6256 - loss: 1.0523 - val_accuracy: 0.7182 - val_loss: 0.8797 - learning_rate: 2.7000e-06
# Epoch 47/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.6350 - loss: 1.0991
# Epoch 47: val_loss did not improve from 0.83243
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.6346 - loss: 1.0985 - val_accuracy: 0.7229 - val_loss: 0.8922 - learning_rate: 2.7000e-06
# Epoch 48/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.7095 - loss: 0.9229
# Epoch 48: val_loss did not improve from 0.83243
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.7086 - loss: 0.9246 - val_accuracy: 0.7288 - val_loss: 0.8618 - learning_rate: 1.0000e-06
# Epoch 49/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.6738 - loss: 0.9958
# Epoch 49: val_loss did not improve from 0.83243
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.6736 - loss: 0.9964 - val_accuracy: 0.7193 - val_loss: 0.8531 - learning_rate: 1.0000e-06
# Epoch 50/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.6468 - loss: 1.0345
# Epoch 50: val_loss did not improve from 0.83243
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.6472 - loss: 1.0330 - val_accuracy: 0.7276 - val_loss: 0.8842 - learning_rate: 1.0000e-06
# Epoch 51/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.6407 - loss: 1.0295
# Epoch 51: val_loss did not improve from 0.83243
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.6416 - loss: 1.0297 - val_accuracy: 0.7182 - val_loss: 0.8436 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained ResNet152 model ===
model_path = "/content/drive/MyDrive/best_resnet152_model.keras"
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_resnet152_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 31s 790ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1 2 3]
# Valid labels: [0, 1]
# Target names: ['abnormal', 'normal']
#
# Predicted sample count per class:
# abnormal: 317
# normal: 529
#
# ✅ Overall Validation Accuracy: 71.23%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     abnormal       0.67      0.61      0.63       348
#       normal       0.74      0.79      0.76       500
#
#    micro avg       0.71      0.71      0.71       848
#    macro avg       0.70      0.70      0.70       848
# weighted avg       0.71      0.71      0.71       848

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
