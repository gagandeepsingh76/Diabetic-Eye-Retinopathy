# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/gagandeep.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

train_dir = "/content/dataset/gagandeep/train"
val_dir = "/content/dataset/gagandeep/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 712 images belonging to 2 classes.
# Found 848 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

base_model = MobileNetV3Large(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# Freeze initial layers (adjust index based on MobileNetV3 architecture depth)
for layer in base_model.layers[:150]:  # MobileNetV3Large has ~270 layers
    layer.trainable = False

# Unfreeze later layers for fine-tuning
for layer in base_model.layers[150:]:
    layer.trainable = True

x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)  # Replace 5 with your actual number of classes if needed

model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
from tensorflow.keras.optimizers import Nadam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define optimizer
optimizer = Nadam(learning_rate=1e-4)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Optional: build the model (only needed if model has not been fit before)
model.build((None, 224, 224, 3))

# Callbacks — updated checkpoint filename
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_mobilenetv3large_model.keras",  # Updated filename
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Fit the model for 51 epochs (no EarlyStopping)
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=21,
    callbacks=[checkpoint, lr_scheduler]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.2039 - loss: 2.1737
# Epoch 1: val_loss improved from inf to 2.17179, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.2059 - loss: 2.1705 - val_accuracy: 0.1474 - val_loss: 2.1718 - learning_rate: 1.0000e-04
# Epoch 2/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.3655 - loss: 1.8273
# Epoch 2: val_loss improved from 2.17179 to 1.66174, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 48s 922ms/step - accuracy: 0.3661 - loss: 1.8257 - val_accuracy: 0.3184 - val_loss: 1.6617 - learning_rate: 1.0000e-04
# Epoch 3/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.4281 - loss: 1.6887
# Epoch 3: val_loss improved from 1.66174 to 1.42519, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.4294 - loss: 1.6845 - val_accuracy: 0.4410 - val_loss: 1.4252 - learning_rate: 1.0000e-04
# Epoch 4/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.5117 - loss: 1.5052
# Epoch 4: val_loss improved from 1.42519 to 1.32191, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 22s 995ms/step - accuracy: 0.5118 - loss: 1.5040 - val_accuracy: 0.5271 - val_loss: 1.3219 - learning_rate: 1.0000e-04
# Epoch 5/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step - accuracy: 0.5149 - loss: 1.4217
# Epoch 5: val_loss improved from 1.32191 to 1.27387, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 968ms/step - accuracy: 0.5164 - loss: 1.4192 - val_accuracy: 0.5590 - val_loss: 1.2739 - learning_rate: 1.0000e-04
# Epoch 6/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.5961 - loss: 1.1818
# Epoch 6: val_loss did not improve from 1.27387
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 937ms/step - accuracy: 0.5963 - loss: 1.1829 - val_accuracy: 0.5519 - val_loss: 1.3370 - learning_rate: 1.0000e-04
# Epoch 7/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.6420 - loss: 1.1706
# Epoch 7: val_loss did not improve from 1.27387
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 873ms/step - accuracy: 0.6431 - loss: 1.1688 - val_accuracy: 0.5354 - val_loss: 1.3660 - learning_rate: 1.0000e-04
# Epoch 8/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.6301 - loss: 1.2364
# Epoch 8: val_loss did not improve from 1.27387
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 933ms/step - accuracy: 0.6318 - loss: 1.2296 - val_accuracy: 0.5660 - val_loss: 1.3434 - learning_rate: 3.0000e-05
# Epoch 9/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.6608 - loss: 1.0752
# Epoch 9: val_loss did not improve from 1.27387
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 893ms/step - accuracy: 0.6610 - loss: 1.0752 - val_accuracy: 0.5637 - val_loss: 1.3059 - learning_rate: 3.0000e-05
# Epoch 10/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.6537 - loss: 1.1183
# Epoch 10: val_loss did not improve from 1.27387
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 919ms/step - accuracy: 0.6540 - loss: 1.1178 - val_accuracy: 0.5849 - val_loss: 1.3308 - learning_rate: 9.0000e-06
# Epoch 11/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.6865 - loss: 1.1029
# Epoch 11: val_loss did not improve from 1.27387
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 932ms/step - accuracy: 0.6863 - loss: 1.1012 - val_accuracy: 0.5696 - val_loss: 1.3412 - learning_rate: 9.0000e-06
# Epoch 12/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.7137 - loss: 1.0597
# Epoch 12: val_loss did not improve from 1.27387
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 875ms/step - accuracy: 0.7134 - loss: 1.0578 - val_accuracy: 0.5825 - val_loss: 1.2986 - learning_rate: 2.7000e-06
# Epoch 13/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.6831 - loss: 1.0164
# Epoch 13: val_loss did not improve from 1.27387
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 943ms/step - accuracy: 0.6837 - loss: 1.0168 - val_accuracy: 0.6038 - val_loss: 1.2926 - learning_rate: 2.7000e-06
# Epoch 14/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.7097 - loss: 0.9745
# Epoch 14: val_loss improved from 1.27387 to 1.26036, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 909ms/step - accuracy: 0.7096 - loss: 0.9760 - val_accuracy: 0.6108 - val_loss: 1.2604 - learning_rate: 1.0000e-06
# Epoch 15/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.6443 - loss: 1.1115
# Epoch 15: val_loss did not improve from 1.26036
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 22s 975ms/step - accuracy: 0.6459 - loss: 1.1076 - val_accuracy: 0.6156 - val_loss: 1.2887 - learning_rate: 1.0000e-06
# Epoch 16/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.6936 - loss: 1.0529
# Epoch 16: val_loss improved from 1.26036 to 1.25838, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 906ms/step - accuracy: 0.6938 - loss: 1.0525 - val_accuracy: 0.6038 - val_loss: 1.2584 - learning_rate: 1.0000e-06
# Epoch 17/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.6758 - loss: 1.0870
# Epoch 17: val_loss improved from 1.25838 to 1.24646, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 22s 990ms/step - accuracy: 0.6758 - loss: 1.0848 - val_accuracy: 0.6333 - val_loss: 1.2465 - learning_rate: 1.0000e-06
# Epoch 18/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.7016 - loss: 0.9764
# Epoch 18: val_loss improved from 1.24646 to 1.22603, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.7011 - loss: 0.9791 - val_accuracy: 0.6203 - val_loss: 1.2260 - learning_rate: 1.0000e-06
# Epoch 19/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.6909 - loss: 0.9722
# Epoch 19: val_loss improved from 1.22603 to 1.21218, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 22s 988ms/step - accuracy: 0.6914 - loss: 0.9730 - val_accuracy: 0.6297 - val_loss: 1.2122 - learning_rate: 1.0000e-06
# Epoch 20/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.6875 - loss: 1.0735
# Epoch 20: val_loss improved from 1.21218 to 1.19324, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.6879 - loss: 1.0702 - val_accuracy: 0.6486 - val_loss: 1.1932 - learning_rate: 1.0000e-06
# Epoch 21/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.6622 - loss: 1.1215
# Epoch 21: val_loss improved from 1.19324 to 1.13298, saving model to /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.6628 - loss: 1.1188 - val_accuracy: 0.6568 - val_loss: 1.1330 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained MobileNetV3Large model ===
model_path = "/content/drive/MyDrive/best_mobilenetv3large_model.keras"  # Updated path
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_mobilenetv3large_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 548ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1 2 3 4]
# Valid labels: [0, 1]
# Target names: ['abnormal', 'normal']
#
# Predicted sample count per class:
# abnormal: 196
# normal: 459
#
# ✅ Overall Validation Accuracy: 66.51%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     abnormal       0.90      0.51      0.65       348
#       normal       0.85      0.78      0.81       500
#
#    micro avg       0.86      0.67      0.75       848
#    macro avg       0.87      0.64      0.73       848
# weighted avg       0.87      0.67      0.74       848

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
