# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/gagandeep.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
from tensorflow.keras.applications.efficientnet import preprocess_input

train_dir = "/content/dataset/gagandeep/train"
val_dir = "/content/dataset/gagandeep/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 712 images belonging to 2 classes.
# Found 848 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

# Load EfficientNetB0 base model without top layers
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze initial layers
for layer in base_model.layers[:100]:
    layer.trainable = False

# Unfreeze remaining layers
for layer in base_model.layers[100:]:
    layer.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)

# Combine base and top layers
model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define optimizer
optimizer = SGD(learning_rate=0.1,momentum=0.9,nesterov=True)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.build((None, 224, 224, 3))

# Callbacks — No EarlyStopping used
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_resnet152_model.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Fit the model for all 51 epochs
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=21,
    callbacks=[checkpoint, lr_scheduler]  # early_stop removed
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5738 - loss: 1.6064
# Epoch 1: val_loss improved from inf to 55.07029, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 97s 2s/step - accuracy: 0.5778 - loss: 1.5965 - val_accuracy: 0.3856 - val_loss: 55.0703 - learning_rate: 0.1000
# Epoch 2/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.6862 - loss: 1.5305
# Epoch 2: val_loss did not improve from 55.07029
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 891ms/step - accuracy: 0.6867 - loss: 1.5232 - val_accuracy: 0.4281 - val_loss: 942.0629 - learning_rate: 0.1000
# Epoch 3/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.7675 - loss: 1.1545
# Epoch 3: val_loss did not improve from 55.07029
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.030000000447034835.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 936ms/step - accuracy: 0.7670 - loss: 1.1508 - val_accuracy: 0.4517 - val_loss: 3464.1565 - learning_rate: 0.1000
# Epoch 4/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.6544 - loss: 1.2855
# Epoch 4: val_loss did not improve from 55.07029
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 876ms/step - accuracy: 0.6552 - loss: 1.2813 - val_accuracy: 0.5896 - val_loss: 2568.4775 - learning_rate: 0.0300
# Epoch 5/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.7110 - loss: 0.8981
# Epoch 5: val_loss did not improve from 55.07029
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.009000000357627868.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 936ms/step - accuracy: 0.7115 - loss: 0.8956 - val_accuracy: 0.6238 - val_loss: 263.5652 - learning_rate: 0.0300
# Epoch 6/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.7553 - loss: 0.8822
# Epoch 6: val_loss did not improve from 55.07029
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 873ms/step - accuracy: 0.7562 - loss: 0.8764 - val_accuracy: 0.6179 - val_loss: 75.0408 - learning_rate: 0.0090
# Epoch 7/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.7740 - loss: 0.7544
# Epoch 7: val_loss improved from 55.07029 to 41.35136, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 22s 967ms/step - accuracy: 0.7743 - loss: 0.7500 - val_accuracy: 0.5908 - val_loss: 41.3514 - learning_rate: 0.0090
# Epoch 8/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.7858 - loss: 0.6366
# Epoch 8: val_loss improved from 41.35136 to 14.14373, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 912ms/step - accuracy: 0.7858 - loss: 0.6349 - val_accuracy: 0.6026 - val_loss: 14.1437 - learning_rate: 0.0090
# Epoch 9/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.7671 - loss: 0.5733
# Epoch 9: val_loss improved from 14.14373 to 4.42959, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 22s 988ms/step - accuracy: 0.7680 - loss: 0.5723 - val_accuracy: 0.5943 - val_loss: 4.4296 - learning_rate: 0.0090
# Epoch 10/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.8127 - loss: 0.4616
# Epoch 10: val_loss improved from 4.42959 to 1.18088, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 939ms/step - accuracy: 0.8129 - loss: 0.4622 - val_accuracy: 0.6050 - val_loss: 1.1809 - learning_rate: 0.0090
# Epoch 11/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8131 - loss: 0.5002
# Epoch 11: val_loss improved from 1.18088 to 0.61595, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 22s 976ms/step - accuracy: 0.8133 - loss: 0.5016 - val_accuracy: 0.6509 - val_loss: 0.6159 - learning_rate: 0.0090
# Epoch 12/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.7990 - loss: 0.4179
# Epoch 12: val_loss did not improve from 0.61595
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.7991 - loss: 0.4186 - val_accuracy: 0.6722 - val_loss: 0.7621 - learning_rate: 0.0090
# Epoch 13/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.8251 - loss: 0.4842
# Epoch 13: val_loss did not improve from 0.61595
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.002700000163167715.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 922ms/step - accuracy: 0.8255 - loss: 0.4831 - val_accuracy: 0.6415 - val_loss: 0.9902 - learning_rate: 0.0090
# Epoch 14/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.8337 - loss: 0.3782
# Epoch 14: val_loss did not improve from 0.61595
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 882ms/step - accuracy: 0.8334 - loss: 0.3783 - val_accuracy: 0.7229 - val_loss: 0.7203 - learning_rate: 0.0027
# Epoch 15/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.8245 - loss: 0.4588
# Epoch 15: val_loss improved from 0.61595 to 0.60508, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 22s 960ms/step - accuracy: 0.8247 - loss: 0.4583 - val_accuracy: 0.7583 - val_loss: 0.6051 - learning_rate: 0.0027
# Epoch 16/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.8187 - loss: 0.4806
# Epoch 16: val_loss improved from 0.60508 to 0.50500, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 965ms/step - accuracy: 0.8194 - loss: 0.4791 - val_accuracy: 0.7936 - val_loss: 0.5050 - learning_rate: 0.0027
# Epoch 17/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.8496 - loss: 0.4229
# Epoch 17: val_loss did not improve from 0.50500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.8497 - loss: 0.4234 - val_accuracy: 0.7877 - val_loss: 0.5583 - learning_rate: 0.0027
# Epoch 18/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.8440 - loss: 0.3920
# Epoch 18: val_loss did not improve from 0.50500
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0008100000210106373.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 21s 936ms/step - accuracy: 0.8434 - loss: 0.3933 - val_accuracy: 0.7818 - val_loss: 0.6014 - learning_rate: 0.0027
# Epoch 19/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.8231 - loss: 0.3849
# Epoch 19: val_loss improved from 0.50500 to 0.49870, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 907ms/step - accuracy: 0.8232 - loss: 0.3861 - val_accuracy: 0.8302 - val_loss: 0.4987 - learning_rate: 8.1000e-04
# Epoch 20/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.8130 - loss: 0.4064
# Epoch 20: val_loss improved from 0.49870 to 0.45149, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 22s 969ms/step - accuracy: 0.8138 - loss: 0.4063 - val_accuracy: 0.8267 - val_loss: 0.4515 - learning_rate: 8.1000e-04
# Epoch 21/21
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.8678 - loss: 0.3517
# Epoch 21: val_loss did not improve from 0.45149
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 22s 956ms/step - accuracy: 0.8675 - loss: 0.3535 - val_accuracy: 0.8090 - val_loss: 0.4542 - learning_rate: 8.1000e-04

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained ResNet152 model ===
model_path = "/content/drive/MyDrive/best_resnet152_model.keras"
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_resnet152_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 22s 629ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1]
# Valid labels: [0, 1]
# Target names: ['abnormal', 'normal']
#
# Predicted sample count per class:
# abnormal: 271
# normal: 577
#
# ✅ Overall Validation Accuracy: 82.67%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     abnormal       0.87      0.68      0.76       348
#       normal       0.81      0.93      0.86       500
#
#     accuracy                           0.83       848
#    macro avg       0.84      0.80      0.81       848
# weighted avg       0.83      0.83      0.82       848

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
