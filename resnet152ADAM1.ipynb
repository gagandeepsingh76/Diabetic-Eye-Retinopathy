# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/gagandeep.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
train_dir = "/content/dataset/gagandeep/train"
val_dir = "/content/dataset/gagandeep/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest')

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 712 images belonging to 2 classes.
# Found 848 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

base_model = ResNet152(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze initial layers
for layer in base_model.layers[:600]:
    layer.trainable = False

# Unfreeze later layers for fine-tuning
for layer in base_model.layers[600:]:
    layer.trainable = True

x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define optimizer
optimizer = Adam(learning_rate=1e-4)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.build((None, 224, 224, 3))

# Callbacks — No EarlyStopping used
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_resnet152_model.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Fit the model for all 51 epochs
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=51,
    callbacks=[checkpoint, lr_scheduler]  # early_stop removed
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.1660 - loss: 2.2315
# Epoch 1: val_loss improved from inf to 1.66537, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.1677 - loss: 2.2282 - val_accuracy: 0.0000e+00 - val_loss: 1.6654 - learning_rate: 1.0000e-04
# Epoch 2/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.2593 - loss: 1.9877
# Epoch 2: val_loss improved from 1.66537 to 1.65136, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.2600 - loss: 1.9879 - val_accuracy: 0.0012 - val_loss: 1.6514 - learning_rate: 1.0000e-04
# Epoch 3/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.2864 - loss: 1.8856
# Epoch 3: val_loss did not improve from 1.65136
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.2866 - loss: 1.8852 - val_accuracy: 0.0012 - val_loss: 1.6851 - learning_rate: 1.0000e-04
# Epoch 4/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.3134 - loss: 1.9270
# Epoch 4: val_loss did not improve from 1.65136
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.3136 - loss: 1.9241 - val_accuracy: 0.0047 - val_loss: 1.6612 - learning_rate: 1.0000e-04
# Epoch 5/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.3375 - loss: 1.7743
# Epoch 5: val_loss did not improve from 1.65136
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.3376 - loss: 1.7748 - val_accuracy: 0.0024 - val_loss: 1.6695 - learning_rate: 3.0000e-05
# Epoch 6/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.3750 - loss: 1.7496
# Epoch 6: val_loss did not improve from 1.65136
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.3747 - loss: 1.7505 - val_accuracy: 0.0047 - val_loss: 1.6601 - learning_rate: 3.0000e-05
# Epoch 7/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.3608 - loss: 1.7774
# Epoch 7: val_loss did not improve from 1.65136
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.3604 - loss: 1.7777 - val_accuracy: 0.0059 - val_loss: 1.6633 - learning_rate: 9.0000e-06
# Epoch 8/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.3582 - loss: 1.7816
# Epoch 8: val_loss did not improve from 1.65136
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.3586 - loss: 1.7815 - val_accuracy: 0.0177 - val_loss: 1.6670 - learning_rate: 9.0000e-06
# Epoch 9/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.3719 - loss: 1.7292
# Epoch 9: val_loss did not improve from 1.65136
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.3720 - loss: 1.7293 - val_accuracy: 0.0212 - val_loss: 1.6675 - learning_rate: 2.7000e-06
# Epoch 10/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.3550 - loss: 1.8053
# Epoch 10: val_loss did not improve from 1.65136
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.3550 - loss: 1.8042 - val_accuracy: 0.0248 - val_loss: 1.6737 - learning_rate: 2.7000e-06
# Epoch 11/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.3560 - loss: 1.7080
# Epoch 11: val_loss did not improve from 1.65136
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.3567 - loss: 1.7084 - val_accuracy: 0.0495 - val_loss: 1.6604 - learning_rate: 1.0000e-06
# Epoch 12/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.3411 - loss: 1.8416
# Epoch 12: val_loss did not improve from 1.65136
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.3417 - loss: 1.8401 - val_accuracy: 0.0849 - val_loss: 1.6594 - learning_rate: 1.0000e-06
# Epoch 13/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.3953 - loss: 1.6640
# Epoch 13: val_loss improved from 1.65136 to 1.64759, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.3945 - loss: 1.6662 - val_accuracy: 0.1215 - val_loss: 1.6476 - learning_rate: 1.0000e-06
# Epoch 14/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.3535 - loss: 1.7146
# Epoch 14: val_loss improved from 1.64759 to 1.64276, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.3534 - loss: 1.7166 - val_accuracy: 0.1321 - val_loss: 1.6428 - learning_rate: 1.0000e-06
# Epoch 15/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.3472 - loss: 1.8332
# Epoch 15: val_loss improved from 1.64276 to 1.62881, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.3482 - loss: 1.8309 - val_accuracy: 0.1922 - val_loss: 1.6288 - learning_rate: 1.0000e-06
# Epoch 16/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - accuracy: 0.4055 - loss: 1.7269
# Epoch 16: val_loss did not improve from 1.62881
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.4044 - loss: 1.7295 - val_accuracy: 0.2252 - val_loss: 1.6321 - learning_rate: 1.0000e-06
# Epoch 17/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.3580 - loss: 1.8100
# Epoch 17: val_loss improved from 1.62881 to 1.59693, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.3589 - loss: 1.8087 - val_accuracy: 0.2866 - val_loss: 1.5969 - learning_rate: 1.0000e-06
# Epoch 18/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 548ms/step - accuracy: 0.3401 - loss: 1.8924
# Epoch 18: val_loss did not improve from 1.59693
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.3408 - loss: 1.8902 - val_accuracy: 0.3302 - val_loss: 1.6005 - learning_rate: 1.0000e-06
# Epoch 19/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.3535 - loss: 1.8092
# Epoch 19: val_loss improved from 1.59693 to 1.56533, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.3537 - loss: 1.8080 - val_accuracy: 0.3679 - val_loss: 1.5653 - learning_rate: 1.0000e-06
# Epoch 20/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.3916 - loss: 1.7300
# Epoch 20: val_loss did not improve from 1.56533
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.3901 - loss: 1.7321 - val_accuracy: 0.3939 - val_loss: 1.5681 - learning_rate: 1.0000e-06
# Epoch 21/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.3706 - loss: 1.6990
# Epoch 21: val_loss improved from 1.56533 to 1.56075, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.3695 - loss: 1.7011 - val_accuracy: 0.3903 - val_loss: 1.5608 - learning_rate: 1.0000e-06
# Epoch 22/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.3742 - loss: 1.7297
# Epoch 22: val_loss improved from 1.56075 to 1.52805, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.3735 - loss: 1.7313 - val_accuracy: 0.4351 - val_loss: 1.5281 - learning_rate: 1.0000e-06
# Epoch 23/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.3105 - loss: 1.7484
# Epoch 23: val_loss improved from 1.52805 to 1.50757, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.3113 - loss: 1.7483 - val_accuracy: 0.4528 - val_loss: 1.5076 - learning_rate: 1.0000e-06
# Epoch 24/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - accuracy: 0.3430 - loss: 1.7475
# Epoch 24: val_loss improved from 1.50757 to 1.50119, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.3431 - loss: 1.7473 - val_accuracy: 0.4823 - val_loss: 1.5012 - learning_rate: 1.0000e-06
# Epoch 25/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - accuracy: 0.3541 - loss: 1.6862
# Epoch 25: val_loss improved from 1.50119 to 1.49357, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.3539 - loss: 1.6870 - val_accuracy: 0.4906 - val_loss: 1.4936 - learning_rate: 1.0000e-06
# Epoch 26/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.3577 - loss: 1.7494
# Epoch 26: val_loss did not improve from 1.49357
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.3580 - loss: 1.7496 - val_accuracy: 0.4788 - val_loss: 1.5024 - learning_rate: 1.0000e-06
# Epoch 27/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.3552 - loss: 1.8380
# Epoch 27: val_loss improved from 1.49357 to 1.44495, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.3552 - loss: 1.8367 - val_accuracy: 0.4929 - val_loss: 1.4449 - learning_rate: 1.0000e-06
# Epoch 28/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - accuracy: 0.3737 - loss: 1.8450
# Epoch 28: val_loss did not improve from 1.44495
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.3730 - loss: 1.8442 - val_accuracy: 0.4929 - val_loss: 1.4876 - learning_rate: 1.0000e-06
# Epoch 29/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.3740 - loss: 1.7227
# Epoch 29: val_loss did not improve from 1.44495
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.3740 - loss: 1.7236 - val_accuracy: 0.5283 - val_loss: 1.4580 - learning_rate: 1.0000e-06
# Epoch 30/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.3679 - loss: 1.7921
# Epoch 30: val_loss did not improve from 1.44495
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.3679 - loss: 1.7921 - val_accuracy: 0.5106 - val_loss: 1.4800 - learning_rate: 1.0000e-06
# Epoch 31/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.3440 - loss: 1.8139
# Epoch 31: val_loss improved from 1.44495 to 1.42004, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.3441 - loss: 1.8130 - val_accuracy: 0.5248 - val_loss: 1.4200 - learning_rate: 1.0000e-06
# Epoch 32/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - accuracy: 0.3476 - loss: 1.8527
# Epoch 32: val_loss did not improve from 1.42004
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.3473 - loss: 1.8523 - val_accuracy: 0.5236 - val_loss: 1.4905 - learning_rate: 1.0000e-06
# Epoch 33/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.3245 - loss: 1.8173
# Epoch 33: val_loss did not improve from 1.42004
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.3261 - loss: 1.8171 - val_accuracy: 0.5130 - val_loss: 1.4476 - learning_rate: 1.0000e-06
# Epoch 34/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.3801 - loss: 1.6860
# Epoch 34: val_loss did not improve from 1.42004
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.3800 - loss: 1.6863 - val_accuracy: 0.5366 - val_loss: 1.4355 - learning_rate: 1.0000e-06
# Epoch 35/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.3781 - loss: 1.7423
# Epoch 35: val_loss did not improve from 1.42004
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.3773 - loss: 1.7439 - val_accuracy: 0.5413 - val_loss: 1.4200 - learning_rate: 1.0000e-06
# Epoch 36/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.3717 - loss: 1.8277
# Epoch 36: val_loss did not improve from 1.42004
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.3709 - loss: 1.8274 - val_accuracy: 0.5283 - val_loss: 1.4449 - learning_rate: 1.0000e-06
# Epoch 37/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.3591 - loss: 1.7473
# Epoch 37: val_loss improved from 1.42004 to 1.40383, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.3594 - loss: 1.7478 - val_accuracy: 0.5413 - val_loss: 1.4038 - learning_rate: 1.0000e-06
# Epoch 38/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.3443 - loss: 1.7675
# Epoch 38: val_loss did not improve from 1.40383
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.3451 - loss: 1.7676 - val_accuracy: 0.5637 - val_loss: 1.4125 - learning_rate: 1.0000e-06
# Epoch 39/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.3578 - loss: 1.8059
# Epoch 39: val_loss improved from 1.40383 to 1.39279, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.3577 - loss: 1.8061 - val_accuracy: 0.5625 - val_loss: 1.3928 - learning_rate: 1.0000e-06
# Epoch 40/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - accuracy: 0.3666 - loss: 1.7606
# Epoch 40: val_loss improved from 1.39279 to 1.39154, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.3667 - loss: 1.7595 - val_accuracy: 0.5554 - val_loss: 1.3915 - learning_rate: 1.0000e-06
# Epoch 41/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.3630 - loss: 1.7162
# Epoch 41: val_loss did not improve from 1.39154
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.3633 - loss: 1.7161 - val_accuracy: 0.5472 - val_loss: 1.4292 - learning_rate: 1.0000e-06
# Epoch 42/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - accuracy: 0.3852 - loss: 1.7137
# Epoch 42: val_loss did not improve from 1.39154
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.3847 - loss: 1.7145 - val_accuracy: 0.5590 - val_loss: 1.4058 - learning_rate: 1.0000e-06
# Epoch 43/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.3406 - loss: 1.7982
# Epoch 43: val_loss did not improve from 1.39154
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.3415 - loss: 1.7951 - val_accuracy: 0.5531 - val_loss: 1.4471 - learning_rate: 1.0000e-06
# Epoch 44/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - accuracy: 0.3469 - loss: 1.7697
# Epoch 44: val_loss did not improve from 1.39154
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.3476 - loss: 1.7689 - val_accuracy: 0.5401 - val_loss: 1.4342 - learning_rate: 1.0000e-06
# Epoch 45/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.3737 - loss: 1.7270
# Epoch 45: val_loss improved from 1.39154 to 1.37207, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.3734 - loss: 1.7279 - val_accuracy: 0.5578 - val_loss: 1.3721 - learning_rate: 1.0000e-06
# Epoch 46/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.3542 - loss: 1.7341
# Epoch 46: val_loss did not improve from 1.37207
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.3552 - loss: 1.7348 - val_accuracy: 0.5566 - val_loss: 1.3826 - learning_rate: 1.0000e-06
# Epoch 47/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - accuracy: 0.3683 - loss: 1.7857
# Epoch 47: val_loss did not improve from 1.37207
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.3683 - loss: 1.7851 - val_accuracy: 0.5460 - val_loss: 1.4094 - learning_rate: 1.0000e-06
# Epoch 48/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 509ms/step - accuracy: 0.4027 - loss: 1.7330
# Epoch 48: val_loss did not improve from 1.37207
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.4022 - loss: 1.7333 - val_accuracy: 0.5542 - val_loss: 1.4019 - learning_rate: 1.0000e-06
# Epoch 49/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.3600 - loss: 1.7502
# Epoch 49: val_loss did not improve from 1.37207
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.3602 - loss: 1.7493 - val_accuracy: 0.5672 - val_loss: 1.3879 - learning_rate: 1.0000e-06
# Epoch 50/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 514ms/step - accuracy: 0.3573 - loss: 1.8237
# Epoch 50: val_loss improved from 1.37207 to 1.35567, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.3573 - loss: 1.8233 - val_accuracy: 0.5743 - val_loss: 1.3557 - learning_rate: 1.0000e-06
# Epoch 51/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.3598 - loss: 1.7419
# Epoch 51: val_loss did not improve from 1.35567
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.3597 - loss: 1.7424 - val_accuracy: 0.5483 - val_loss: 1.4062 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained ResNet152 model ===
model_path = "/content/drive/MyDrive/best_resnet152_model.keras"
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_resnet152_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 34s 891ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1 2 3 4]
# Valid labels: [0, 1]
# Target names: ['abnormal', 'normal']
#
# Predicted sample count per class:
# abnormal: 376
# normal: 314
#
# ✅ Overall Validation Accuracy: 58.49%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     abnormal       0.63      0.68      0.66       348
#       normal       0.82      0.52      0.63       500
#
#    micro avg       0.72      0.58      0.64       848
#    macro avg       0.73      0.60      0.65       848
# weighted avg       0.74      0.58      0.64       848

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
