# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/b3.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152 to InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
train_dir = "/content/dataset/b3/train"
val_dir = "/content/dataset/b3/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator


# === Data generators ===
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

# === Load image data ===
train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(299, 299),  # ✅ Required input size for InceptionV3
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(299, 299),  # ✅ Required input size for InceptionV3
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 712 images belonging to 2 classes.
# Found 848 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

# Load InceptionV3 as base model
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))  # 🔄 Updated input size

# Freeze initial layers
for layer in base_model.layers[:200]:  # 🔄 InceptionV3 has fewer layers than ResNet152
    layer.trainable = False

# Unfreeze later layers
for layer in base_model.layers[200:]:
    layer.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define optimizer
optimizer = SGD(learning_rate=0.01,momentum=0.9,nesterov=True)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# ✅ Updated input shape for InceptionV3
model.build((None, 299, 299, 3))

# ✅ Updated checkpoint filename to reflect InceptionV3
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_inceptionv3_model.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Train the model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=40,
    callbacks=[checkpoint, lr_scheduler]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3811 - loss: 1.7660
# Epoch 1: val_loss improved from inf to 1.93831, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.3864 - loss: 1.7530 - val_accuracy: 0.5979 - val_loss: 1.9383 - learning_rate: 0.0100
# Epoch 2/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.7430 - loss: 0.7783
# Epoch 2: val_loss improved from 1.93831 to 0.99838, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.7443 - loss: 0.7746 - val_accuracy: 0.6663 - val_loss: 0.9984 - learning_rate: 0.0100
# Epoch 3/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.8148 - loss: 0.5083
# Epoch 3: val_loss improved from 0.99838 to 0.67849, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.8141 - loss: 0.5081 - val_accuracy: 0.7052 - val_loss: 0.6785 - learning_rate: 0.0100
# Epoch 4/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 821ms/step - accuracy: 0.8053 - loss: 0.4477
# Epoch 4: val_loss did not improve from 0.67849
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8060 - loss: 0.4474 - val_accuracy: 0.6333 - val_loss: 1.2322 - learning_rate: 0.0100
# Epoch 5/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 725ms/step - accuracy: 0.8309 - loss: 0.3997
# Epoch 5: val_loss did not improve from 0.67849
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0029999999329447745.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8311 - loss: 0.3996 - val_accuracy: 0.6804 - val_loss: 0.9276 - learning_rate: 0.0100
# Epoch 6/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.8651 - loss: 0.3293
# Epoch 6: val_loss did not improve from 0.67849
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8653 - loss: 0.3292 - val_accuracy: 0.6993 - val_loss: 0.6853 - learning_rate: 0.0030
# Epoch 7/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - accuracy: 0.8612 - loss: 0.3446
# Epoch 7: val_loss improved from 0.67849 to 0.60575, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.8614 - loss: 0.3438 - val_accuracy: 0.6958 - val_loss: 0.6058 - learning_rate: 0.0030
# Epoch 8/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 815ms/step - accuracy: 0.8844 - loss: 0.2839
# Epoch 8: val_loss improved from 0.60575 to 0.55051, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8838 - loss: 0.2851 - val_accuracy: 0.7347 - val_loss: 0.5505 - learning_rate: 0.0030
# Epoch 9/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 815ms/step - accuracy: 0.8867 - loss: 0.3049
# Epoch 9: val_loss improved from 0.55051 to 0.52389, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8864 - loss: 0.3047 - val_accuracy: 0.7429 - val_loss: 0.5239 - learning_rate: 0.0030
# Epoch 10/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 818ms/step - accuracy: 0.9328 - loss: 0.1980
# Epoch 10: val_loss improved from 0.52389 to 0.48625, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9319 - loss: 0.1991 - val_accuracy: 0.7818 - val_loss: 0.4863 - learning_rate: 0.0030
# Epoch 11/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.9195 - loss: 0.2014
# Epoch 11: val_loss did not improve from 0.48625
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9192 - loss: 0.2022 - val_accuracy: 0.7488 - val_loss: 0.5587 - learning_rate: 0.0030
# Epoch 12/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 782ms/step - accuracy: 0.9141 - loss: 0.2013
# Epoch 12: val_loss did not improve from 0.48625
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0009000000078231095.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9140 - loss: 0.2021 - val_accuracy: 0.7642 - val_loss: 0.5228 - learning_rate: 0.0030
# Epoch 13/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9052 - loss: 0.2270
# Epoch 13: val_loss did not improve from 0.48625
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9055 - loss: 0.2269 - val_accuracy: 0.7618 - val_loss: 0.4966 - learning_rate: 9.0000e-04
# Epoch 14/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9248 - loss: 0.2271
# Epoch 14: val_loss improved from 0.48625 to 0.45912, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9244 - loss: 0.2276 - val_accuracy: 0.7925 - val_loss: 0.4591 - learning_rate: 9.0000e-04
# Epoch 15/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 818ms/step - accuracy: 0.9152 - loss: 0.2044
# Epoch 15: val_loss improved from 0.45912 to 0.41927, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9150 - loss: 0.2049 - val_accuracy: 0.8208 - val_loss: 0.4193 - learning_rate: 9.0000e-04
# Epoch 16/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.8951 - loss: 0.2124
# Epoch 16: val_loss improved from 0.41927 to 0.40845, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8955 - loss: 0.2126 - val_accuracy: 0.8137 - val_loss: 0.4085 - learning_rate: 9.0000e-04
# Epoch 17/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 815ms/step - accuracy: 0.9344 - loss: 0.2037
# Epoch 17: val_loss improved from 0.40845 to 0.36615, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9344 - loss: 0.2034 - val_accuracy: 0.8349 - val_loss: 0.3662 - learning_rate: 9.0000e-04
# Epoch 18/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 884ms/step - accuracy: 0.9226 - loss: 0.1672
# Epoch 18: val_loss improved from 0.36615 to 0.35789, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9229 - loss: 0.1675 - val_accuracy: 0.8443 - val_loss: 0.3579 - learning_rate: 9.0000e-04
# Epoch 19/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 737ms/step - accuracy: 0.9053 - loss: 0.2061
# Epoch 19: val_loss did not improve from 0.35789
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 75s 2s/step - accuracy: 0.9058 - loss: 0.2054 - val_accuracy: 0.8502 - val_loss: 0.3766 - learning_rate: 9.0000e-04
# Epoch 20/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 771ms/step - accuracy: 0.9405 - loss: 0.1538
# Epoch 20: val_loss improved from 0.35789 to 0.32643, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9399 - loss: 0.1547 - val_accuracy: 0.8538 - val_loss: 0.3264 - learning_rate: 9.0000e-04
# Epoch 21/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 887ms/step - accuracy: 0.9278 - loss: 0.1974
# Epoch 21: val_loss did not improve from 0.32643
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9280 - loss: 0.1971 - val_accuracy: 0.8314 - val_loss: 0.4109 - learning_rate: 9.0000e-04
# Epoch 22/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.9328 - loss: 0.1857
# Epoch 22: val_loss did not improve from 0.32643
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00026999999536201356.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9326 - loss: 0.1857 - val_accuracy: 0.8608 - val_loss: 0.3447 - learning_rate: 9.0000e-04
# Epoch 23/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - accuracy: 0.9077 - loss: 0.1962
# Epoch 23: val_loss did not improve from 0.32643
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9084 - loss: 0.1951 - val_accuracy: 0.8597 - val_loss: 0.3872 - learning_rate: 2.7000e-04
# Epoch 24/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 832ms/step - accuracy: 0.9597 - loss: 0.1478
# Epoch 24: val_loss did not improve from 0.32643
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 8.099999686237424e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9592 - loss: 0.1482 - val_accuracy: 0.8585 - val_loss: 0.3560 - learning_rate: 2.7000e-04
# Epoch 25/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - accuracy: 0.9389 - loss: 0.1494
# Epoch 25: val_loss did not improve from 0.32643
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9387 - loss: 0.1502 - val_accuracy: 0.8608 - val_loss: 0.3633 - learning_rate: 8.1000e-05
# Epoch 26/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9414 - loss: 0.1627
# Epoch 26: val_loss did not improve from 0.32643
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9414 - loss: 0.1625 - val_accuracy: 0.8420 - val_loss: 0.4007 - learning_rate: 8.1000e-05
# Epoch 27/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9050 - loss: 0.2066
# Epoch 27: val_loss did not improve from 0.32643
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9059 - loss: 0.2052 - val_accuracy: 0.8526 - val_loss: 0.3495 - learning_rate: 2.4300e-05
# Epoch 28/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9188 - loss: 0.1828
# Epoch 28: val_loss did not improve from 0.32643
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.289999848580919e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9189 - loss: 0.1831 - val_accuracy: 0.8620 - val_loss: 0.3591 - learning_rate: 2.4300e-05
# Epoch 29/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.8832 - loss: 0.2959
# Epoch 29: val_loss did not improve from 0.32643
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8843 - loss: 0.2931 - val_accuracy: 0.8573 - val_loss: 0.3648 - learning_rate: 7.2900e-06
# Epoch 30/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9473 - loss: 0.1635
# Epoch 30: val_loss did not improve from 0.32643
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.186999927289435e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 58s 3s/step - accuracy: 0.9471 - loss: 0.1635 - val_accuracy: 0.8526 - val_loss: 0.3534 - learning_rate: 7.2900e-06
# Epoch 31/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 765ms/step - accuracy: 0.9265 - loss: 0.1705
# Epoch 31: val_loss did not improve from 0.32643
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9266 - loss: 0.1712 - val_accuracy: 0.8479 - val_loss: 0.3755 - learning_rate: 2.1870e-06
# Epoch 32/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9370 - loss: 0.1928
# Epoch 32: val_loss did not improve from 0.32643
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9369 - loss: 0.1924 - val_accuracy: 0.8561 - val_loss: 0.3642 - learning_rate: 2.1870e-06
# Epoch 33/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - accuracy: 0.9516 - loss: 0.1400
# Epoch 33: val_loss did not improve from 0.32643
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9514 - loss: 0.1407 - val_accuracy: 0.8573 - val_loss: 0.3624 - learning_rate: 1.0000e-06
# Epoch 34/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9284 - loss: 0.1617
# Epoch 34: val_loss did not improve from 0.32643
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9282 - loss: 0.1620 - val_accuracy: 0.8644 - val_loss: 0.3548 - learning_rate: 1.0000e-06
# Epoch 35/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 759ms/step - accuracy: 0.9468 - loss: 0.1542
# Epoch 35: val_loss did not improve from 0.32643
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9466 - loss: 0.1547 - val_accuracy: 0.8514 - val_loss: 0.3796 - learning_rate: 1.0000e-06
# Epoch 36/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 737ms/step - accuracy: 0.9446 - loss: 0.1398
# Epoch 36: val_loss did not improve from 0.32643
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9443 - loss: 0.1406 - val_accuracy: 0.8420 - val_loss: 0.3614 - learning_rate: 1.0000e-06
# Epoch 37/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - accuracy: 0.9346 - loss: 0.1349
# Epoch 37: val_loss did not improve from 0.32643
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9345 - loss: 0.1353 - val_accuracy: 0.8632 - val_loss: 0.3862 - learning_rate: 1.0000e-06
# Epoch 38/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - accuracy: 0.9201 - loss: 0.1971
# Epoch 38: val_loss did not improve from 0.32643
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9205 - loss: 0.1962 - val_accuracy: 0.8467 - val_loss: 0.3974 - learning_rate: 1.0000e-06
# Epoch 39/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - accuracy: 0.9570 - loss: 0.1568
# Epoch 39: val_loss did not improve from 0.32643
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9566 - loss: 0.1573 - val_accuracy: 0.8420 - val_loss: 0.3994 - learning_rate: 1.0000e-06
# Epoch 40/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 764ms/step - accuracy: 0.9444 - loss: 0.1741
# Epoch 40: val_loss did not improve from 0.32643
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9445 - loss: 0.1739 - val_accuracy: 0.8550 - val_loss: 0.3870 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained ResNet152 model ===
model_path = "/content/drive/MyDrive/best_inceptionv3_model.keras"
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_inceptionv3_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 32s 943ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1]
# Valid labels: [0, 1]
# Target names: ['abnormal', 'normal']
#
# Predicted sample count per class:
# abnormal: 318
# normal: 530
#
# ✅ Overall Validation Accuracy: 85.85%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     abnormal       0.86      0.78      0.82       348
#       normal       0.86      0.91      0.88       500
#
#     accuracy                           0.86       848
#    macro avg       0.86      0.85      0.85       848
# weighted avg       0.86      0.86      0.86       848

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
