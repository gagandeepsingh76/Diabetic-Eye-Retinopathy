# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/b2.8.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152 to InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
train_dir = "/content/dataset/b2.8/train"
val_dir = "/content/dataset/b2.8/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator


# === Data generators ===
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

# === Load image data ===
train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(299, 299),  # ✅ Required input size for InceptionV3
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(299, 299),  # ✅ Required input size for InceptionV3
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 712 images belonging to 2 classes.
# Found 848 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

# Load InceptionV3 as base model
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))  # 🔄 Updated input size

# Freeze initial layers
for layer in base_model.layers[:200]:  # 🔄 InceptionV3 has fewer layers than ResNet152
    layer.trainable = False

# Unfreeze later layers
for layer in base_model.layers[200:]:
    layer.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define optimizer
optimizer = SGD(learning_rate=0.01,momentum=0.9,nesterov=True)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# ✅ Updated input shape for InceptionV3
model.build((None, 299, 299, 3))

# ✅ Updated checkpoint filename to reflect InceptionV3
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_inceptionv3_model.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Train the model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=40,
    callbacks=[checkpoint, lr_scheduler]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4591 - loss: 1.6872
# Epoch 1: val_loss improved from inf to 2.16146, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 121s 4s/step - accuracy: 0.4645 - loss: 1.6752 - val_accuracy: 0.5318 - val_loss: 2.1615 - learning_rate: 0.0100
# Epoch 2/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 810ms/step - accuracy: 0.7692 - loss: 0.7742
# Epoch 2: val_loss improved from 2.16146 to 0.75486, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 74s 2s/step - accuracy: 0.7707 - loss: 0.7696 - val_accuracy: 0.7406 - val_loss: 0.7549 - learning_rate: 0.0100
# Epoch 3/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 910ms/step - accuracy: 0.8540 - loss: 0.4832
# Epoch 3: val_loss did not improve from 0.75486
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8536 - loss: 0.4829 - val_accuracy: 0.6462 - val_loss: 1.0457 - learning_rate: 0.0100
# Epoch 4/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 787ms/step - accuracy: 0.8466 - loss: 0.4106
# Epoch 4: val_loss did not improve from 0.75486
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0029999999329447745.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8470 - loss: 0.4108 - val_accuracy: 0.6392 - val_loss: 0.8939 - learning_rate: 0.0100
# Epoch 5/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 817ms/step - accuracy: 0.8584 - loss: 0.4065
# Epoch 5: val_loss improved from 0.75486 to 0.69006, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8581 - loss: 0.4063 - val_accuracy: 0.6616 - val_loss: 0.6901 - learning_rate: 0.0030
# Epoch 6/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 898ms/step - accuracy: 0.8212 - loss: 0.4423
# Epoch 6: val_loss improved from 0.69006 to 0.47819, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.8218 - loss: 0.4406 - val_accuracy: 0.7500 - val_loss: 0.4782 - learning_rate: 0.0030
# Epoch 7/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.8405 - loss: 0.3375
# Epoch 7: val_loss improved from 0.47819 to 0.42350, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 63s 3s/step - accuracy: 0.8413 - loss: 0.3370 - val_accuracy: 0.8125 - val_loss: 0.4235 - learning_rate: 0.0030
# Epoch 8/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 905ms/step - accuracy: 0.8960 - loss: 0.3086
# Epoch 8: val_loss improved from 0.42350 to 0.39747, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8957 - loss: 0.3088 - val_accuracy: 0.7925 - val_loss: 0.3975 - learning_rate: 0.0030
# Epoch 9/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 954ms/step - accuracy: 0.8753 - loss: 0.2877
# Epoch 9: val_loss did not improve from 0.39747
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.8764 - loss: 0.2862 - val_accuracy: 0.8031 - val_loss: 0.4051 - learning_rate: 0.0030
# Epoch 10/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - accuracy: 0.8791 - loss: 0.2910
# Epoch 10: val_loss did not improve from 0.39747
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0009000000078231095.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8793 - loss: 0.2908 - val_accuracy: 0.7547 - val_loss: 0.4969 - learning_rate: 0.0030
# Epoch 11/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 753ms/step - accuracy: 0.8379 - loss: 0.4061
# Epoch 11: val_loss did not improve from 0.39747
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8374 - loss: 0.4069 - val_accuracy: 0.7264 - val_loss: 0.5840 - learning_rate: 9.0000e-04
# Epoch 12/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 809ms/step - accuracy: 0.8398 - loss: 0.4115
# Epoch 12: val_loss did not improve from 0.39747
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00026999999536201356.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8407 - loss: 0.4095 - val_accuracy: 0.7618 - val_loss: 0.4995 - learning_rate: 9.0000e-04
# Epoch 13/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 792ms/step - accuracy: 0.8399 - loss: 0.3181
# Epoch 13: val_loss did not improve from 0.39747
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8396 - loss: 0.3191 - val_accuracy: 0.7854 - val_loss: 0.4563 - learning_rate: 2.7000e-04
# Epoch 14/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.8663 - loss: 0.2870
# Epoch 14: val_loss did not improve from 0.39747
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 8.099999686237424e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8662 - loss: 0.2876 - val_accuracy: 0.7983 - val_loss: 0.4440 - learning_rate: 2.7000e-04
# Epoch 15/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 759ms/step - accuracy: 0.8600 - loss: 0.3557
# Epoch 15: val_loss did not improve from 0.39747
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8604 - loss: 0.3540 - val_accuracy: 0.7972 - val_loss: 0.4351 - learning_rate: 8.1000e-05
# Epoch 16/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 757ms/step - accuracy: 0.8939 - loss: 0.2749
# Epoch 16: val_loss did not improve from 0.39747
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8937 - loss: 0.2757 - val_accuracy: 0.8149 - val_loss: 0.4150 - learning_rate: 8.1000e-05
# Epoch 17/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - accuracy: 0.8834 - loss: 0.2870
# Epoch 17: val_loss did not improve from 0.39747
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8831 - loss: 0.2878 - val_accuracy: 0.8031 - val_loss: 0.4131 - learning_rate: 2.4300e-05
# Epoch 18/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - accuracy: 0.8907 - loss: 0.2686
# Epoch 18: val_loss did not improve from 0.39747
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 7.289999848580919e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8907 - loss: 0.2695 - val_accuracy: 0.7995 - val_loss: 0.4320 - learning_rate: 2.4300e-05
# Epoch 19/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 761ms/step - accuracy: 0.8829 - loss: 0.2895
# Epoch 19: val_loss did not improve from 0.39747
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8824 - loss: 0.2900 - val_accuracy: 0.8302 - val_loss: 0.4085 - learning_rate: 7.2900e-06
# Epoch 20/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.8702 - loss: 0.2990
# Epoch 20: val_loss improved from 0.39747 to 0.39033, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.8701 - loss: 0.2992 - val_accuracy: 0.8384 - val_loss: 0.3903 - learning_rate: 7.2900e-06
# Epoch 21/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 846ms/step - accuracy: 0.8898 - loss: 0.2791
# Epoch 21: val_loss did not improve from 0.39033
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8892 - loss: 0.2807 - val_accuracy: 0.8267 - val_loss: 0.3909 - learning_rate: 7.2900e-06
# Epoch 22/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 811ms/step - accuracy: 0.8563 - loss: 0.3221
# Epoch 22: val_loss did not improve from 0.39033
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.186999927289435e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.8567 - loss: 0.3217 - val_accuracy: 0.8196 - val_loss: 0.3941 - learning_rate: 7.2900e-06
# Epoch 23/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - accuracy: 0.8835 - loss: 0.2739
# Epoch 23: val_loss did not improve from 0.39033
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8829 - loss: 0.2757 - val_accuracy: 0.8337 - val_loss: 0.3915 - learning_rate: 2.1870e-06
# Epoch 24/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 770ms/step - accuracy: 0.8645 - loss: 0.3389
# Epoch 24: val_loss did not improve from 0.39033
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8644 - loss: 0.3389 - val_accuracy: 0.8208 - val_loss: 0.4075 - learning_rate: 2.1870e-06
# Epoch 25/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 789ms/step - accuracy: 0.8818 - loss: 0.2852
# Epoch 25: val_loss did not improve from 0.39033
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8818 - loss: 0.2857 - val_accuracy: 0.8125 - val_loss: 0.4354 - learning_rate: 1.0000e-06
# Epoch 26/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 766ms/step - accuracy: 0.8811 - loss: 0.3011
# Epoch 26: val_loss did not improve from 0.39033
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8812 - loss: 0.3010 - val_accuracy: 0.8184 - val_loss: 0.4087 - learning_rate: 1.0000e-06
# Epoch 27/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 757ms/step - accuracy: 0.8529 - loss: 0.3346
# Epoch 27: val_loss improved from 0.39033 to 0.37326, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8535 - loss: 0.3335 - val_accuracy: 0.8408 - val_loss: 0.3733 - learning_rate: 1.0000e-06
# Epoch 28/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 903ms/step - accuracy: 0.8845 - loss: 0.3236
# Epoch 28: val_loss did not improve from 0.37326
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8840 - loss: 0.3234 - val_accuracy: 0.8184 - val_loss: 0.4096 - learning_rate: 1.0000e-06
# Epoch 29/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 791ms/step - accuracy: 0.8840 - loss: 0.2967
# Epoch 29: val_loss did not improve from 0.37326
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8841 - loss: 0.2970 - val_accuracy: 0.8455 - val_loss: 0.3742 - learning_rate: 1.0000e-06
# Epoch 30/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 761ms/step - accuracy: 0.8764 - loss: 0.3180
# Epoch 30: val_loss did not improve from 0.37326
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.8764 - loss: 0.3179 - val_accuracy: 0.8349 - val_loss: 0.4174 - learning_rate: 1.0000e-06
# Epoch 31/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 764ms/step - accuracy: 0.8768 - loss: 0.2981
# Epoch 31: val_loss did not improve from 0.37326
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.8762 - loss: 0.2995 - val_accuracy: 0.8184 - val_loss: 0.3998 - learning_rate: 1.0000e-06
# Epoch 32/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 752ms/step - accuracy: 0.8788 - loss: 0.2982
# Epoch 32: val_loss did not improve from 0.37326
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8786 - loss: 0.2982 - val_accuracy: 0.8349 - val_loss: 0.3993 - learning_rate: 1.0000e-06
# Epoch 33/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.8815 - loss: 0.2744
# Epoch 33: val_loss did not improve from 0.37326
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8820 - loss: 0.2745 - val_accuracy: 0.8302 - val_loss: 0.4040 - learning_rate: 1.0000e-06
# Epoch 34/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.9012 - loss: 0.2503
# Epoch 34: val_loss improved from 0.37326 to 0.37316, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9009 - loss: 0.2509 - val_accuracy: 0.8267 - val_loss: 0.3732 - learning_rate: 1.0000e-06
# Epoch 35/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 904ms/step - accuracy: 0.8731 - loss: 0.3027
# Epoch 35: val_loss did not improve from 0.37316
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8731 - loss: 0.3031 - val_accuracy: 0.8302 - val_loss: 0.3905 - learning_rate: 1.0000e-06
# Epoch 36/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.8527 - loss: 0.3561
# Epoch 36: val_loss did not improve from 0.37316
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8531 - loss: 0.3550 - val_accuracy: 0.8361 - val_loss: 0.3939 - learning_rate: 1.0000e-06
# Epoch 37/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 749ms/step - accuracy: 0.8861 - loss: 0.3063
# Epoch 37: val_loss did not improve from 0.37316
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8858 - loss: 0.3064 - val_accuracy: 0.8184 - val_loss: 0.4103 - learning_rate: 1.0000e-06
# Epoch 38/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - accuracy: 0.8795 - loss: 0.2873
# Epoch 38: val_loss did not improve from 0.37316
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8794 - loss: 0.2881 - val_accuracy: 0.8479 - val_loss: 0.3934 - learning_rate: 1.0000e-06
# Epoch 39/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 753ms/step - accuracy: 0.8879 - loss: 0.3055
# Epoch 39: val_loss did not improve from 0.37316
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8882 - loss: 0.3046 - val_accuracy: 0.8278 - val_loss: 0.4144 - learning_rate: 1.0000e-06
# Epoch 40/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 761ms/step - accuracy: 0.8549 - loss: 0.3122
# Epoch 40: val_loss did not improve from 0.37316
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8558 - loss: 0.3113 - val_accuracy: 0.8432 - val_loss: 0.4174 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained ResNet152 model ===
model_path = "/content/drive/MyDrive/best_inceptionv3_model.keras"
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_inceptionv3_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 33s 956ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1]
# Valid labels: [0, 1]
# Target names: ['abnormal', 'normal']
#
# Predicted sample count per class:
# abnormal: 290
# normal: 558
#
# ✅ Overall Validation Accuracy: 82.55%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     abnormal       0.84      0.70      0.77       348
#       normal       0.82      0.91      0.86       500
#
#     accuracy                           0.83       848
#    macro avg       0.83      0.81      0.81       848
# weighted avg       0.83      0.83      0.82       848

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
