# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/b0.6.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152 to InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
train_dir = "/content/dataset/b0.6/train"
val_dir = "/content/dataset/b0.6/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator


# === Data generators ===
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

# === Load image data ===
train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(299, 299),  # ✅ Required input size for InceptionV3
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(299, 299),  # ✅ Required input size for InceptionV3
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 712 images belonging to 2 classes.
# Found 848 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

# Load InceptionV3 as base model
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))  # 🔄 Updated input size

# Freeze initial layers
for layer in base_model.layers[:200]:  # 🔄 InceptionV3 has fewer layers than ResNet152
    layer.trainable = False

# Unfreeze later layers
for layer in base_model.layers[200:]:
    layer.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define optimizer
optimizer = SGD(learning_rate=0.01,momentum=0.9,nesterov=True)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# ✅ Updated input shape for InceptionV3
model.build((None, 299, 299, 3))

# ✅ Updated checkpoint filename to reflect InceptionV3
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_inceptionv3_model.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Train the model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=40,
    callbacks=[checkpoint, lr_scheduler]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4595 - loss: 1.5969
# Epoch 1: val_loss improved from inf to 5.53729, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.4657 - loss: 1.5827 - val_accuracy: 0.4163 - val_loss: 5.5373 - learning_rate: 0.0100
# Epoch 2/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 839ms/step - accuracy: 0.8081 - loss: 0.6718
# Epoch 2: val_loss improved from 5.53729 to 1.39106, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8086 - loss: 0.6693 - val_accuracy: 0.5884 - val_loss: 1.3911 - learning_rate: 0.0100
# Epoch 3/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 865ms/step - accuracy: 0.8314 - loss: 0.5054
# Epoch 3: val_loss did not improve from 1.39106
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.8316 - loss: 0.5055 - val_accuracy: 0.5979 - val_loss: 1.3934 - learning_rate: 0.0100
# Epoch 4/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 761ms/step - accuracy: 0.8465 - loss: 0.4507
# Epoch 4: val_loss did not improve from 1.39106
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0029999999329447745.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8468 - loss: 0.4495 - val_accuracy: 0.6191 - val_loss: 2.9254 - learning_rate: 0.0100
# Epoch 5/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 751ms/step - accuracy: 0.8517 - loss: 0.3895
# Epoch 5: val_loss improved from 1.39106 to 1.24614, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.8527 - loss: 0.3870 - val_accuracy: 0.7075 - val_loss: 1.2461 - learning_rate: 0.0030
# Epoch 6/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 879ms/step - accuracy: 0.8794 - loss: 0.3146
# Epoch 6: val_loss improved from 1.24614 to 0.56588, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8798 - loss: 0.3146 - val_accuracy: 0.7571 - val_loss: 0.5659 - learning_rate: 0.0030
# Epoch 7/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 871ms/step - accuracy: 0.8799 - loss: 0.2969
# Epoch 7: val_loss improved from 0.56588 to 0.46653, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8799 - loss: 0.2977 - val_accuracy: 0.7877 - val_loss: 0.4665 - learning_rate: 0.0030
# Epoch 8/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 933ms/step - accuracy: 0.8619 - loss: 0.2951
# Epoch 8: val_loss did not improve from 0.46653
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8624 - loss: 0.2945 - val_accuracy: 0.7771 - val_loss: 0.4786 - learning_rate: 0.0030
# Epoch 9/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.8961 - loss: 0.2967
# Epoch 9: val_loss improved from 0.46653 to 0.46600, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8965 - loss: 0.2955 - val_accuracy: 0.7948 - val_loss: 0.4660 - learning_rate: 0.0030
# Epoch 10/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - accuracy: 0.9025 - loss: 0.2728
# Epoch 10: val_loss improved from 0.46600 to 0.39008, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9023 - loss: 0.2734 - val_accuracy: 0.8101 - val_loss: 0.3901 - learning_rate: 0.0030
# Epoch 11/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 861ms/step - accuracy: 0.9260 - loss: 0.2004
# Epoch 11: val_loss did not improve from 0.39008
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9257 - loss: 0.2007 - val_accuracy: 0.8196 - val_loss: 0.4117 - learning_rate: 0.0030
# Epoch 12/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 722ms/step - accuracy: 0.9019 - loss: 0.2458
# Epoch 12: val_loss improved from 0.39008 to 0.36647, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9022 - loss: 0.2454 - val_accuracy: 0.8443 - val_loss: 0.3665 - learning_rate: 0.0030
# Epoch 13/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 872ms/step - accuracy: 0.9235 - loss: 0.2035
# Epoch 13: val_loss did not improve from 0.36647
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9235 - loss: 0.2046 - val_accuracy: 0.8255 - val_loss: 0.3880 - learning_rate: 0.0030
# Epoch 14/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.8856 - loss: 0.3189
# Epoch 14: val_loss did not improve from 0.36647
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0009000000078231095.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8861 - loss: 0.3176 - val_accuracy: 0.8420 - val_loss: 0.3742 - learning_rate: 0.0030
# Epoch 15/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9169 - loss: 0.2012
# Epoch 15: val_loss improved from 0.36647 to 0.34803, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9170 - loss: 0.2012 - val_accuracy: 0.8455 - val_loss: 0.3480 - learning_rate: 9.0000e-04
# Epoch 16/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.8977 - loss: 0.2258
# Epoch 16: val_loss did not improve from 0.34803
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.8981 - loss: 0.2255 - val_accuracy: 0.8420 - val_loss: 0.3605 - learning_rate: 9.0000e-04
# Epoch 17/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 751ms/step - accuracy: 0.8929 - loss: 0.2533
# Epoch 17: val_loss did not improve from 0.34803
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00026999999536201356.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8933 - loss: 0.2533 - val_accuracy: 0.8491 - val_loss: 0.3482 - learning_rate: 9.0000e-04
# Epoch 18/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - accuracy: 0.9400 - loss: 0.1870
# Epoch 18: val_loss did not improve from 0.34803
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9401 - loss: 0.1867 - val_accuracy: 0.8420 - val_loss: 0.3590 - learning_rate: 2.7000e-04
# Epoch 19/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 721ms/step - accuracy: 0.9004 - loss: 0.3253
# Epoch 19: val_loss did not improve from 0.34803
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.099999686237424e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9012 - loss: 0.3211 - val_accuracy: 0.8278 - val_loss: 0.3793 - learning_rate: 2.7000e-04
# Epoch 20/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - accuracy: 0.9270 - loss: 0.1800
# Epoch 20: val_loss did not improve from 0.34803
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9267 - loss: 0.1810 - val_accuracy: 0.8231 - val_loss: 0.3764 - learning_rate: 8.1000e-05
# Epoch 21/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 737ms/step - accuracy: 0.9132 - loss: 0.2294
# Epoch 21: val_loss did not improve from 0.34803
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9133 - loss: 0.2293 - val_accuracy: 0.8396 - val_loss: 0.3540 - learning_rate: 8.1000e-05
# Epoch 22/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9366 - loss: 0.1846
# Epoch 22: val_loss did not improve from 0.34803
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9367 - loss: 0.1842 - val_accuracy: 0.8550 - val_loss: 0.3534 - learning_rate: 2.4300e-05
# Epoch 23/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 725ms/step - accuracy: 0.9166 - loss: 0.2122
# Epoch 23: val_loss did not improve from 0.34803
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 7.289999848580919e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9170 - loss: 0.2116 - val_accuracy: 0.8491 - val_loss: 0.3627 - learning_rate: 2.4300e-05
# Epoch 24/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - accuracy: 0.9145 - loss: 0.2095
# Epoch 24: val_loss did not improve from 0.34803
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9148 - loss: 0.2092 - val_accuracy: 0.8455 - val_loss: 0.3597 - learning_rate: 7.2900e-06
# Epoch 25/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 751ms/step - accuracy: 0.9159 - loss: 0.2140
# Epoch 25: val_loss did not improve from 0.34803
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 2.186999927289435e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9160 - loss: 0.2133 - val_accuracy: 0.8420 - val_loss: 0.3654 - learning_rate: 7.2900e-06
# Epoch 26/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9298 - loss: 0.1695
# Epoch 26: val_loss did not improve from 0.34803
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9297 - loss: 0.1698 - val_accuracy: 0.8502 - val_loss: 0.3497 - learning_rate: 2.1870e-06
# Epoch 27/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 784ms/step - accuracy: 0.9173 - loss: 0.2271
# Epoch 27: val_loss improved from 0.34803 to 0.34428, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9172 - loss: 0.2268 - val_accuracy: 0.8632 - val_loss: 0.3443 - learning_rate: 2.1870e-06
# Epoch 28/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 823ms/step - accuracy: 0.9187 - loss: 0.2041
# Epoch 28: val_loss did not improve from 0.34428
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9194 - loss: 0.2027 - val_accuracy: 0.8538 - val_loss: 0.3639 - learning_rate: 2.1870e-06
# Epoch 29/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9412 - loss: 0.1713
# Epoch 29: val_loss improved from 0.34428 to 0.34335, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9407 - loss: 0.1725 - val_accuracy: 0.8502 - val_loss: 0.3433 - learning_rate: 2.1870e-06
# Epoch 30/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 828ms/step - accuracy: 0.9398 - loss: 0.1785
# Epoch 30: val_loss improved from 0.34335 to 0.33746, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9392 - loss: 0.1791 - val_accuracy: 0.8502 - val_loss: 0.3375 - learning_rate: 2.1870e-06
# Epoch 31/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.9355 - loss: 0.1811
# Epoch 31: val_loss did not improve from 0.33746
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9356 - loss: 0.1809 - val_accuracy: 0.8420 - val_loss: 0.3615 - learning_rate: 2.1870e-06
# Epoch 32/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - accuracy: 0.9388 - loss: 0.1747
# Epoch 32: val_loss did not improve from 0.33746
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9384 - loss: 0.1758 - val_accuracy: 0.8502 - val_loss: 0.3599 - learning_rate: 2.1870e-06
# Epoch 33/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 787ms/step - accuracy: 0.9274 - loss: 0.1955
# Epoch 33: val_loss did not improve from 0.33746
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9278 - loss: 0.1948 - val_accuracy: 0.8561 - val_loss: 0.3593 - learning_rate: 1.0000e-06
# Epoch 34/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9094 - loss: 0.2378
# Epoch 34: val_loss improved from 0.33746 to 0.33336, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9100 - loss: 0.2369 - val_accuracy: 0.8514 - val_loss: 0.3334 - learning_rate: 1.0000e-06
# Epoch 35/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.9323 - loss: 0.1988
# Epoch 35: val_loss did not improve from 0.33336
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9321 - loss: 0.1987 - val_accuracy: 0.8514 - val_loss: 0.3596 - learning_rate: 1.0000e-06
# Epoch 36/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9307 - loss: 0.1741
# Epoch 36: val_loss did not improve from 0.33336
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9310 - loss: 0.1735 - val_accuracy: 0.8491 - val_loss: 0.3713 - learning_rate: 1.0000e-06
# Epoch 37/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9326 - loss: 0.1836
# Epoch 37: val_loss did not improve from 0.33336
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9320 - loss: 0.1845 - val_accuracy: 0.8290 - val_loss: 0.4211 - learning_rate: 1.0000e-06
# Epoch 38/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - accuracy: 0.9324 - loss: 0.2033
# Epoch 38: val_loss did not improve from 0.33336
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9324 - loss: 0.2027 - val_accuracy: 0.8538 - val_loss: 0.3676 - learning_rate: 1.0000e-06
# Epoch 39/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 757ms/step - accuracy: 0.9358 - loss: 0.1768
# Epoch 39: val_loss did not improve from 0.33336
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9355 - loss: 0.1773 - val_accuracy: 0.8373 - val_loss: 0.3703 - learning_rate: 1.0000e-06
# Epoch 40/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 766ms/step - accuracy: 0.9216 - loss: 0.2503
# Epoch 40: val_loss did not improve from 0.33336
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9218 - loss: 0.2490 - val_accuracy: 0.8491 - val_loss: 0.3992 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained ResNet152 model ===
model_path = "/content/drive/MyDrive/best_inceptionv3_model.keras"
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_inceptionv3_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 32s 957ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1]
# Valid labels: [0, 1]
# Target names: ['abnormal', 'normal']
#
# Predicted sample count per class:
# abnormal: 301
# normal: 547
#
# ✅ Overall Validation Accuracy: 85.73%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     abnormal       0.88      0.76      0.81       348
#       normal       0.85      0.93      0.88       500
#
#     accuracy                           0.86       848
#    macro avg       0.86      0.84      0.85       848
# weighted avg       0.86      0.86      0.86       848

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
