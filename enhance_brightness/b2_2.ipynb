# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/b2.2.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152 to InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
train_dir = "/content/dataset/b2.2/train"
val_dir = "/content/dataset/b2.2/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator


# === Data generators ===
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

# === Load image data ===
train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(299, 299),  # ✅ Required input size for InceptionV3
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(299, 299),  # ✅ Required input size for InceptionV3
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 712 images belonging to 2 classes.
# Found 848 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

# Load InceptionV3 as base model
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))  # 🔄 Updated input size

# Freeze initial layers
for layer in base_model.layers[:200]:  # 🔄 InceptionV3 has fewer layers than ResNet152
    layer.trainable = False

# Unfreeze later layers
for layer in base_model.layers[200:]:
    layer.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define optimizer
optimizer = SGD(learning_rate=0.01,momentum=0.9,nesterov=True)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# ✅ Updated input shape for InceptionV3
model.build((None, 299, 299, 3))

# ✅ Updated checkpoint filename to reflect InceptionV3
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_inceptionv3_model.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Train the model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=40,
    callbacks=[checkpoint, lr_scheduler]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4697 - loss: 1.5871
# Epoch 1: val_loss improved from inf to 4.04307, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 118s 4s/step - accuracy: 0.4756 - loss: 1.5727 - val_accuracy: 0.5259 - val_loss: 4.0431 - learning_rate: 0.0100
# Epoch 2/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 897ms/step - accuracy: 0.7868 - loss: 0.7511
# Epoch 2: val_loss improved from 4.04307 to 2.01842, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.7872 - loss: 0.7496 - val_accuracy: 0.6557 - val_loss: 2.0184 - learning_rate: 0.0100
# Epoch 3/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 901ms/step - accuracy: 0.8273 - loss: 0.5524
# Epoch 3: val_loss improved from 2.01842 to 0.49238, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8282 - loss: 0.5498 - val_accuracy: 0.8172 - val_loss: 0.4924 - learning_rate: 0.0100
# Epoch 4/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 762ms/step - accuracy: 0.8500 - loss: 0.4630
# Epoch 4: val_loss did not improve from 0.49238
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.8502 - loss: 0.4622 - val_accuracy: 0.7665 - val_loss: 0.5151 - learning_rate: 0.0100
# Epoch 5/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - accuracy: 0.8428 - loss: 0.4275
# Epoch 5: val_loss did not improve from 0.49238
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0029999999329447745.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8431 - loss: 0.4267 - val_accuracy: 0.7358 - val_loss: 0.7284 - learning_rate: 0.0100
# Epoch 6/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.8673 - loss: 0.3814
# Epoch 6: val_loss did not improve from 0.49238
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8674 - loss: 0.3813 - val_accuracy: 0.7972 - val_loss: 0.5568 - learning_rate: 0.0030
# Epoch 7/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 749ms/step - accuracy: 0.8982 - loss: 0.2760
# Epoch 7: val_loss improved from 0.49238 to 0.40933, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.8979 - loss: 0.2769 - val_accuracy: 0.8149 - val_loss: 0.4093 - learning_rate: 0.0030
# Epoch 8/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.8922 - loss: 0.2682
# Epoch 8: val_loss did not improve from 0.40933
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8925 - loss: 0.2678 - val_accuracy: 0.7913 - val_loss: 0.4359 - learning_rate: 0.0030
# Epoch 9/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.8754 - loss: 0.3150
# Epoch 9: val_loss improved from 0.40933 to 0.40051, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.8760 - loss: 0.3144 - val_accuracy: 0.8101 - val_loss: 0.4005 - learning_rate: 0.0030
# Epoch 10/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 900ms/step - accuracy: 0.9139 - loss: 0.1984
# Epoch 10: val_loss did not improve from 0.40051
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9142 - loss: 0.1984 - val_accuracy: 0.7830 - val_loss: 0.4374 - learning_rate: 0.0030
# Epoch 11/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 752ms/step - accuracy: 0.9242 - loss: 0.2148
# Epoch 11: val_loss did not improve from 0.40051
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0009000000078231095.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9240 - loss: 0.2152 - val_accuracy: 0.7783 - val_loss: 0.4487 - learning_rate: 0.0030
# Epoch 12/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 761ms/step - accuracy: 0.9413 - loss: 0.1549
# Epoch 12: val_loss did not improve from 0.40051
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9412 - loss: 0.1555 - val_accuracy: 0.7642 - val_loss: 0.4763 - learning_rate: 9.0000e-04
# Epoch 13/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 756ms/step - accuracy: 0.9207 - loss: 0.2238
# Epoch 13: val_loss did not improve from 0.40051
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00026999999536201356.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9208 - loss: 0.2231 - val_accuracy: 0.7854 - val_loss: 0.4371 - learning_rate: 9.0000e-04
# Epoch 14/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 751ms/step - accuracy: 0.9218 - loss: 0.2402
# Epoch 14: val_loss did not improve from 0.40051
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9219 - loss: 0.2396 - val_accuracy: 0.7995 - val_loss: 0.4100 - learning_rate: 2.7000e-04
# Epoch 15/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 762ms/step - accuracy: 0.9126 - loss: 0.2291
# Epoch 15: val_loss did not improve from 0.40051
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.099999686237424e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 59s 3s/step - accuracy: 0.9122 - loss: 0.2292 - val_accuracy: 0.8125 - val_loss: 0.4420 - learning_rate: 2.7000e-04
# Epoch 16/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 811ms/step - accuracy: 0.9063 - loss: 0.2530
# Epoch 16: val_loss did not improve from 0.40051
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9066 - loss: 0.2518 - val_accuracy: 0.8160 - val_loss: 0.4293 - learning_rate: 8.1000e-05
# Epoch 17/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 772ms/step - accuracy: 0.9261 - loss: 0.2049
# Epoch 17: val_loss improved from 0.40051 to 0.39902, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9262 - loss: 0.2046 - val_accuracy: 0.8243 - val_loss: 0.3990 - learning_rate: 8.1000e-05
# Epoch 18/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 907ms/step - accuracy: 0.9181 - loss: 0.1871
# Epoch 18: val_loss did not improve from 0.39902
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9188 - loss: 0.1868 - val_accuracy: 0.8243 - val_loss: 0.4088 - learning_rate: 8.1000e-05
# Epoch 19/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 777ms/step - accuracy: 0.9206 - loss: 0.2138
# Epoch 19: val_loss did not improve from 0.39902
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9203 - loss: 0.2146 - val_accuracy: 0.8255 - val_loss: 0.4050 - learning_rate: 8.1000e-05
# Epoch 20/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 755ms/step - accuracy: 0.8877 - loss: 0.2731
# Epoch 20: val_loss improved from 0.39902 to 0.37672, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8882 - loss: 0.2724 - val_accuracy: 0.8373 - val_loss: 0.3767 - learning_rate: 2.4300e-05
# Epoch 21/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 906ms/step - accuracy: 0.9170 - loss: 0.1858
# Epoch 21: val_loss did not improve from 0.37672
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9171 - loss: 0.1858 - val_accuracy: 0.8420 - val_loss: 0.3844 - learning_rate: 2.4300e-05
# Epoch 22/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 874ms/step - accuracy: 0.9225 - loss: 0.2173
# Epoch 22: val_loss did not improve from 0.37672
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 7.289999848580919e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9221 - loss: 0.2180 - val_accuracy: 0.8443 - val_loss: 0.3772 - learning_rate: 2.4300e-05
# Epoch 23/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 785ms/step - accuracy: 0.9232 - loss: 0.1871
# Epoch 23: val_loss did not improve from 0.37672
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9235 - loss: 0.1870 - val_accuracy: 0.8373 - val_loss: 0.3860 - learning_rate: 7.2900e-06
# Epoch 24/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 759ms/step - accuracy: 0.9260 - loss: 0.1844
# Epoch 24: val_loss did not improve from 0.37672
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.186999927289435e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9261 - loss: 0.1846 - val_accuracy: 0.8314 - val_loss: 0.3955 - learning_rate: 7.2900e-06
# Epoch 25/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 779ms/step - accuracy: 0.9020 - loss: 0.2074
# Epoch 25: val_loss did not improve from 0.37672
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9029 - loss: 0.2060 - val_accuracy: 0.8443 - val_loss: 0.3974 - learning_rate: 2.1870e-06
# Epoch 26/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - accuracy: 0.9110 - loss: 0.1970
# Epoch 26: val_loss improved from 0.37672 to 0.37026, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9116 - loss: 0.1968 - val_accuracy: 0.8479 - val_loss: 0.3703 - learning_rate: 2.1870e-06
# Epoch 27/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 845ms/step - accuracy: 0.9214 - loss: 0.1883
# Epoch 27: val_loss improved from 0.37026 to 0.34549, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9214 - loss: 0.1887 - val_accuracy: 0.8715 - val_loss: 0.3455 - learning_rate: 2.1870e-06
# Epoch 28/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - accuracy: 0.9356 - loss: 0.1710
# Epoch 28: val_loss did not improve from 0.34549
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9348 - loss: 0.1725 - val_accuracy: 0.8597 - val_loss: 0.3850 - learning_rate: 2.1870e-06
# Epoch 29/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.9276 - loss: 0.1786
# Epoch 29: val_loss did not improve from 0.34549
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9268 - loss: 0.1797 - val_accuracy: 0.8514 - val_loss: 0.3926 - learning_rate: 2.1870e-06
# Epoch 30/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 760ms/step - accuracy: 0.9137 - loss: 0.1978
# Epoch 30: val_loss did not improve from 0.34549
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9139 - loss: 0.1973 - val_accuracy: 0.8420 - val_loss: 0.3817 - learning_rate: 1.0000e-06
# Epoch 31/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - accuracy: 0.9169 - loss: 0.2122
# Epoch 31: val_loss did not improve from 0.34549
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9171 - loss: 0.2115 - val_accuracy: 0.8361 - val_loss: 0.3849 - learning_rate: 1.0000e-06
# Epoch 32/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.9147 - loss: 0.2236
# Epoch 32: val_loss did not improve from 0.34549
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9150 - loss: 0.2227 - val_accuracy: 0.8408 - val_loss: 0.4103 - learning_rate: 1.0000e-06
# Epoch 33/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 753ms/step - accuracy: 0.9337 - loss: 0.1719
# Epoch 33: val_loss did not improve from 0.34549
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9335 - loss: 0.1722 - val_accuracy: 0.8514 - val_loss: 0.3628 - learning_rate: 1.0000e-06
# Epoch 34/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 750ms/step - accuracy: 0.9247 - loss: 0.1793
# Epoch 34: val_loss did not improve from 0.34549
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9245 - loss: 0.1793 - val_accuracy: 0.8491 - val_loss: 0.3864 - learning_rate: 1.0000e-06
# Epoch 35/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 821ms/step - accuracy: 0.9449 - loss: 0.1732
# Epoch 35: val_loss did not improve from 0.34549
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9441 - loss: 0.1744 - val_accuracy: 0.8561 - val_loss: 0.3626 - learning_rate: 1.0000e-06
# Epoch 36/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - accuracy: 0.9314 - loss: 0.1997
# Epoch 36: val_loss did not improve from 0.34549
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9316 - loss: 0.1996 - val_accuracy: 0.8538 - val_loss: 0.4196 - learning_rate: 1.0000e-06
# Epoch 37/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - accuracy: 0.9197 - loss: 0.1804
# Epoch 37: val_loss did not improve from 0.34549
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9195 - loss: 0.1814 - val_accuracy: 0.8550 - val_loss: 0.3603 - learning_rate: 1.0000e-06
# Epoch 38/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 756ms/step - accuracy: 0.9072 - loss: 0.2132
# Epoch 38: val_loss did not improve from 0.34549
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9074 - loss: 0.2137 - val_accuracy: 0.8502 - val_loss: 0.3750 - learning_rate: 1.0000e-06
# Epoch 39/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 746ms/step - accuracy: 0.9290 - loss: 0.1979
# Epoch 39: val_loss did not improve from 0.34549
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9287 - loss: 0.1986 - val_accuracy: 0.8502 - val_loss: 0.3674 - learning_rate: 1.0000e-06
# Epoch 40/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 749ms/step - accuracy: 0.9372 - loss: 0.1990
# Epoch 40: val_loss did not improve from 0.34549
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9369 - loss: 0.1989 - val_accuracy: 0.8443 - val_loss: 0.3785 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained ResNet152 model ===
model_path = "/content/drive/MyDrive/best_inceptionv3_model.keras"
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_inceptionv3_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 33s 956ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1]
# Valid labels: [0, 1]
# Target names: ['abnormal', 'normal']
#
# Predicted sample count per class:
# abnormal: 287
# normal: 561
#
# ✅ Overall Validation Accuracy: 84.79%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     abnormal       0.88      0.73      0.80       348
#       normal       0.83      0.93      0.88       500
#
#     accuracy                           0.85       848
#    macro avg       0.86      0.83      0.84       848
# weighted avg       0.85      0.85      0.84       848

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
