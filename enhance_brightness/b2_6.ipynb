# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/b2.6.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152 to InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
train_dir = "/content/dataset/b2.6/train"
val_dir = "/content/dataset/b2.6/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator


# === Data generators ===
train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

# === Load image data ===
train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(299, 299),  # ✅ Required input size for InceptionV3
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(299, 299),  # ✅ Required input size for InceptionV3
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 712 images belonging to 2 classes.
# Found 848 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import InceptionV3  # 🔄 Changed from ResNet152
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

# Load InceptionV3 as base model
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))  # 🔄 Updated input size

# Freeze initial layers
for layer in base_model.layers[:200]:  # 🔄 InceptionV3 has fewer layers than ResNet152
    layer.trainable = False

# Unfreeze later layers
for layer in base_model.layers[200:]:
    layer.trainable = True

# Add custom classification head
x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define optimizer
optimizer = SGD(learning_rate=0.01,momentum=0.9,nesterov=True)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# ✅ Updated input shape for InceptionV3
model.build((None, 299, 299, 3))

# ✅ Updated checkpoint filename to reflect InceptionV3
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_inceptionv3_model.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Train the model
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=40,
    callbacks=[checkpoint, lr_scheduler]
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4328 - loss: 1.7503
# Epoch 1: val_loss improved from inf to 2.39483, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 117s 4s/step - accuracy: 0.4392 - loss: 1.7355 - val_accuracy: 0.4257 - val_loss: 2.3948 - learning_rate: 0.0100
# Epoch 2/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 796ms/step - accuracy: 0.7703 - loss: 0.7618
# Epoch 2: val_loss improved from 2.39483 to 1.14550, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.7704 - loss: 0.7618 - val_accuracy: 0.6781 - val_loss: 1.1455 - learning_rate: 0.0100
# Epoch 3/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 892ms/step - accuracy: 0.7961 - loss: 0.5391
# Epoch 3: val_loss improved from 1.14550 to 0.59506, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.7967 - loss: 0.5375 - val_accuracy: 0.7712 - val_loss: 0.5951 - learning_rate: 0.0100
# Epoch 4/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 888ms/step - accuracy: 0.8614 - loss: 0.3775
# Epoch 4: val_loss did not improve from 0.59506
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8610 - loss: 0.3791 - val_accuracy: 0.7370 - val_loss: 0.5974 - learning_rate: 0.0100
# Epoch 5/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 827ms/step - accuracy: 0.8291 - loss: 0.4186
# Epoch 5: val_loss improved from 0.59506 to 0.57272, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.8299 - loss: 0.4169 - val_accuracy: 0.7689 - val_loss: 0.5727 - learning_rate: 0.0100
# Epoch 6/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 884ms/step - accuracy: 0.8281 - loss: 0.4411
# Epoch 6: val_loss did not improve from 0.57272
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8290 - loss: 0.4384 - val_accuracy: 0.7429 - val_loss: 0.5857 - learning_rate: 0.0100
# Epoch 7/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - accuracy: 0.8890 - loss: 0.2842
# Epoch 7: val_loss did not improve from 0.57272
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0029999999329447745.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.8884 - loss: 0.2852 - val_accuracy: 0.6993 - val_loss: 0.6669 - learning_rate: 0.0100
# Epoch 8/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 766ms/step - accuracy: 0.8657 - loss: 0.3038
# Epoch 8: val_loss improved from 0.57272 to 0.44459, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.8666 - loss: 0.3027 - val_accuracy: 0.8231 - val_loss: 0.4446 - learning_rate: 0.0030
# Epoch 9/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 952ms/step - accuracy: 0.8773 - loss: 0.3145
# Epoch 9: val_loss improved from 0.44459 to 0.41885, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.8783 - loss: 0.3118 - val_accuracy: 0.8101 - val_loss: 0.4188 - learning_rate: 0.0030
# Epoch 10/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - accuracy: 0.9088 - loss: 0.2351
# Epoch 10: val_loss improved from 0.41885 to 0.39267, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 2s/step - accuracy: 0.9088 - loss: 0.2354 - val_accuracy: 0.8184 - val_loss: 0.3927 - learning_rate: 0.0030
# Epoch 11/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.9063 - loss: 0.2273
# Epoch 11: val_loss did not improve from 0.39267
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9064 - loss: 0.2271 - val_accuracy: 0.8160 - val_loss: 0.4104 - learning_rate: 0.0030
# Epoch 12/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - accuracy: 0.9324 - loss: 0.1840
# Epoch 12: val_loss did not improve from 0.39267
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0009000000078231095.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9317 - loss: 0.1846 - val_accuracy: 0.7960 - val_loss: 0.4267 - learning_rate: 0.0030
# Epoch 13/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - accuracy: 0.9090 - loss: 0.2255
# Epoch 13: val_loss did not improve from 0.39267
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9098 - loss: 0.2240 - val_accuracy: 0.8066 - val_loss: 0.4306 - learning_rate: 9.0000e-04
# Epoch 14/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 789ms/step - accuracy: 0.9335 - loss: 0.1684
# Epoch 14: val_loss did not improve from 0.39267
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00026999999536201356.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9330 - loss: 0.1701 - val_accuracy: 0.8113 - val_loss: 0.4159 - learning_rate: 9.0000e-04
# Epoch 15/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - accuracy: 0.8879 - loss: 0.2271
# Epoch 15: val_loss did not improve from 0.39267
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.8891 - loss: 0.2254 - val_accuracy: 0.8243 - val_loss: 0.3954 - learning_rate: 2.7000e-04
# Epoch 16/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - accuracy: 0.9082 - loss: 0.2050
# Epoch 16: val_loss improved from 0.39267 to 0.38656, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9087 - loss: 0.2047 - val_accuracy: 0.8160 - val_loss: 0.3866 - learning_rate: 2.7000e-04
# Epoch 17/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.9325 - loss: 0.1674
# Epoch 17: val_loss did not improve from 0.38656
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9327 - loss: 0.1676 - val_accuracy: 0.8349 - val_loss: 0.3957 - learning_rate: 2.7000e-04
# Epoch 18/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - accuracy: 0.9249 - loss: 0.2198
# Epoch 18: val_loss improved from 0.38656 to 0.37746, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9248 - loss: 0.2195 - val_accuracy: 0.8384 - val_loss: 0.3775 - learning_rate: 2.7000e-04
# Epoch 19/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.9175 - loss: 0.2021
# Epoch 19: val_loss improved from 0.37746 to 0.37629, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9177 - loss: 0.2018 - val_accuracy: 0.8349 - val_loss: 0.3763 - learning_rate: 2.7000e-04
# Epoch 20/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 850ms/step - accuracy: 0.9272 - loss: 0.1985
# Epoch 20: val_loss improved from 0.37629 to 0.35273, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9274 - loss: 0.1980 - val_accuracy: 0.8550 - val_loss: 0.3527 - learning_rate: 2.7000e-04
# Epoch 21/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 891ms/step - accuracy: 0.9410 - loss: 0.1529
# Epoch 21: val_loss did not improve from 0.35273
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9410 - loss: 0.1533 - val_accuracy: 0.8408 - val_loss: 0.3761 - learning_rate: 2.7000e-04
# Epoch 22/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 748ms/step - accuracy: 0.9076 - loss: 0.2533
# Epoch 22: val_loss did not improve from 0.35273
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 8.099999686237424e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9090 - loss: 0.2500 - val_accuracy: 0.8632 - val_loss: 0.3604 - learning_rate: 2.7000e-04
# Epoch 23/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - accuracy: 0.9242 - loss: 0.2222
# Epoch 23: val_loss improved from 0.35273 to 0.35103, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9244 - loss: 0.2208 - val_accuracy: 0.8573 - val_loss: 0.3510 - learning_rate: 8.1000e-05
# Epoch 24/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - accuracy: 0.9263 - loss: 0.2142
# Epoch 24: val_loss improved from 0.35103 to 0.32431, saving model to /content/drive/MyDrive/best_inceptionv3_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9267 - loss: 0.2131 - val_accuracy: 0.8656 - val_loss: 0.3243 - learning_rate: 8.1000e-05
# Epoch 25/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 850ms/step - accuracy: 0.9369 - loss: 0.1693
# Epoch 25: val_loss did not improve from 0.32431
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9371 - loss: 0.1687 - val_accuracy: 0.8455 - val_loss: 0.3647 - learning_rate: 8.1000e-05
# Epoch 26/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - accuracy: 0.9212 - loss: 0.1811
# Epoch 26: val_loss did not improve from 0.32431
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9217 - loss: 0.1806 - val_accuracy: 0.8420 - val_loss: 0.3701 - learning_rate: 8.1000e-05
# Epoch 27/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 790ms/step - accuracy: 0.9418 - loss: 0.1662
# Epoch 27: val_loss did not improve from 0.32431
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9419 - loss: 0.1658 - val_accuracy: 0.8585 - val_loss: 0.3613 - learning_rate: 2.4300e-05
# Epoch 28/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 742ms/step - accuracy: 0.9371 - loss: 0.1862
# Epoch 28: val_loss did not improve from 0.32431
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 7.289999848580919e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9367 - loss: 0.1861 - val_accuracy: 0.8561 - val_loss: 0.3517 - learning_rate: 2.4300e-05
# Epoch 29/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - accuracy: 0.9453 - loss: 0.1648
# Epoch 29: val_loss did not improve from 0.32431
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9449 - loss: 0.1654 - val_accuracy: 0.8561 - val_loss: 0.3391 - learning_rate: 7.2900e-06
# Epoch 30/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 744ms/step - accuracy: 0.9355 - loss: 0.1528
# Epoch 30: val_loss did not improve from 0.32431
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.186999927289435e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9353 - loss: 0.1532 - val_accuracy: 0.8432 - val_loss: 0.3527 - learning_rate: 7.2900e-06
# Epoch 31/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 788ms/step - accuracy: 0.9344 - loss: 0.1945
# Epoch 31: val_loss did not improve from 0.32431
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9347 - loss: 0.1938 - val_accuracy: 0.8467 - val_loss: 0.3528 - learning_rate: 2.1870e-06
# Epoch 32/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 788ms/step - accuracy: 0.9558 - loss: 0.1314
# Epoch 32: val_loss did not improve from 0.32431
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9551 - loss: 0.1327 - val_accuracy: 0.8561 - val_loss: 0.3477 - learning_rate: 2.1870e-06
# Epoch 33/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 751ms/step - accuracy: 0.9409 - loss: 0.1697
# Epoch 33: val_loss did not improve from 0.32431
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9406 - loss: 0.1698 - val_accuracy: 0.8608 - val_loss: 0.3404 - learning_rate: 1.0000e-06
# Epoch 34/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 750ms/step - accuracy: 0.9404 - loss: 0.1725
# Epoch 34: val_loss did not improve from 0.32431
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9399 - loss: 0.1732 - val_accuracy: 0.8491 - val_loss: 0.3526 - learning_rate: 1.0000e-06
# Epoch 35/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 741ms/step - accuracy: 0.9518 - loss: 0.1221
# Epoch 35: val_loss did not improve from 0.32431
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9519 - loss: 0.1221 - val_accuracy: 0.8420 - val_loss: 0.3586 - learning_rate: 1.0000e-06
# Epoch 36/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 751ms/step - accuracy: 0.9192 - loss: 0.1696
# Epoch 36: val_loss did not improve from 0.32431
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 58s 3s/step - accuracy: 0.9196 - loss: 0.1698 - val_accuracy: 0.8561 - val_loss: 0.3678 - learning_rate: 1.0000e-06
# Epoch 37/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.9367 - loss: 0.1746
# Epoch 37: val_loss did not improve from 0.32431
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9366 - loss: 0.1750 - val_accuracy: 0.8632 - val_loss: 0.3511 - learning_rate: 1.0000e-06
# Epoch 38/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 785ms/step - accuracy: 0.9313 - loss: 0.1929
# Epoch 38: val_loss did not improve from 0.32431
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9313 - loss: 0.1924 - val_accuracy: 0.8526 - val_loss: 0.3588 - learning_rate: 1.0000e-06
# Epoch 39/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.9555 - loss: 0.1519
# Epoch 39: val_loss did not improve from 0.32431
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9549 - loss: 0.1524 - val_accuracy: 0.8550 - val_loss: 0.3688 - learning_rate: 1.0000e-06
# Epoch 40/40
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - accuracy: 0.9114 - loss: 0.2024
# Epoch 40: val_loss did not improve from 0.32431
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9121 - loss: 0.2010 - val_accuracy: 0.8573 - val_loss: 0.3522 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained ResNet152 model ===
model_path = "/content/drive/MyDrive/best_inceptionv3_model.keras"
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_inceptionv3_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 32s 951ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1]
# Valid labels: [0, 1]
# Target names: ['abnormal', 'normal']
#
# Predicted sample count per class:
# abnormal: 287
# normal: 561
#
# ✅ Overall Validation Accuracy: 84.08%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     abnormal       0.87      0.72      0.79       348
#       normal       0.83      0.93      0.87       500
#
#     accuracy                           0.84       848
#    macro avg       0.85      0.82      0.83       848
# weighted avg       0.84      0.84      0.84       848

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
