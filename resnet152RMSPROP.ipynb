# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os

zip_path = "/content/drive/MyDrive/gagandeep.zip"
extract_path = "/content/dataset"

if not os.path.exists(extract_path):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_path)

print(" Dataset extracted.")
# Out:
#  Dataset extracted.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
train_dir = "/content/dataset/gagandeep/train"
val_dir = "/content/dataset/gagandeep/val"

from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest'
)

val_gen = ImageDataGenerator(rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.25,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    shear_range=0.15,
    fill_mode='nearest')

train_data = train_gen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=True
)

val_data = val_gen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='sparse',
    shuffle=False
)
# Out:
# Found 712 images belonging to 2 classes.
# Found 848 images belonging to 2 classes.

# %%
from tensorflow.keras.applications import ResNet152
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

base_model = ResNet152(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze initial layers
for layer in base_model.layers[:600]:
    layer.trainable = False

# Unfreeze later layers for fine-tuning
for layer in base_model.layers[600:]:
    layer.trainable = True

x = GlobalAveragePooling2D()(base_model.output)
x = BatchNormalization()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = BatchNormalization()(x)
output = Dense(5, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# Define optimizer
optimizer = RMSprop(learning_rate=1e-4)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.build((None, 224, 224, 3))

# Callbacks — No EarlyStopping used
checkpoint = ModelCheckpoint(
    "/content/drive/MyDrive/best_resnet152_model.keras",
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.3,
    patience=2,
    verbose=1,
    min_lr=1e-6
)

# Fit the model for all 51 epochs
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=51,
    callbacks=[checkpoint, lr_scheduler]  # early_stop removed
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.2398 - loss: 2.1837
# Epoch 1: val_loss improved from inf to 1.39928, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.2403 - loss: 2.1803 - val_accuracy: 0.4104 - val_loss: 1.3993 - learning_rate: 1.0000e-04
# Epoch 2/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.3245 - loss: 1.8762
# Epoch 2: val_loss improved from 1.39928 to 1.34007, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.3241 - loss: 1.8771 - val_accuracy: 0.4104 - val_loss: 1.3401 - learning_rate: 1.0000e-04
# Epoch 3/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.3360 - loss: 1.8664
# Epoch 3: val_loss improved from 1.34007 to 1.30595, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.3357 - loss: 1.8657 - val_accuracy: 0.4092 - val_loss: 1.3059 - learning_rate: 1.0000e-04
# Epoch 4/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - accuracy: 0.3301 - loss: 1.8355
# Epoch 4: val_loss improved from 1.30595 to 1.28601, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.3294 - loss: 1.8360 - val_accuracy: 0.5908 - val_loss: 1.2860 - learning_rate: 1.0000e-04
# Epoch 5/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 522ms/step - accuracy: 0.3416 - loss: 1.7509
# Epoch 5: val_loss did not improve from 1.28601
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.3416 - loss: 1.7504 - val_accuracy: 0.5991 - val_loss: 1.2916 - learning_rate: 1.0000e-04
# Epoch 6/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.3392 - loss: 1.7170
# Epoch 6: val_loss improved from 1.28601 to 1.27968, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.3400 - loss: 1.7137 - val_accuracy: 0.6073 - val_loss: 1.2797 - learning_rate: 1.0000e-04
# Epoch 7/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - accuracy: 0.3604 - loss: 1.7400
# Epoch 7: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.3616 - loss: 1.7387 - val_accuracy: 0.6061 - val_loss: 1.3118 - learning_rate: 1.0000e-04
# Epoch 8/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.4194 - loss: 1.5926
# Epoch 8: val_loss did not improve from 1.27968
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.4193 - loss: 1.5931 - val_accuracy: 0.6167 - val_loss: 1.3239 - learning_rate: 1.0000e-04
# Epoch 9/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.4338 - loss: 1.5594
# Epoch 9: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4330 - loss: 1.5609 - val_accuracy: 0.6050 - val_loss: 1.3329 - learning_rate: 3.0000e-05
# Epoch 10/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.4570 - loss: 1.5153
# Epoch 10: val_loss did not improve from 1.27968
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.4560 - loss: 1.5194 - val_accuracy: 0.6120 - val_loss: 1.3580 - learning_rate: 3.0000e-05
# Epoch 11/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.4199 - loss: 1.6093
# Epoch 11: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4211 - loss: 1.6073 - val_accuracy: 0.5955 - val_loss: 1.3781 - learning_rate: 9.0000e-06
# Epoch 12/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.4525 - loss: 1.5648
# Epoch 12: val_loss did not improve from 1.27968
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.4520 - loss: 1.5640 - val_accuracy: 0.5649 - val_loss: 1.3956 - learning_rate: 9.0000e-06
# Epoch 13/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.4181 - loss: 1.5782
# Epoch 13: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4192 - loss: 1.5779 - val_accuracy: 0.5047 - val_loss: 1.4166 - learning_rate: 2.7000e-06
# Epoch 14/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.4423 - loss: 1.6130
# Epoch 14: val_loss did not improve from 1.27968
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1e-06.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4424 - loss: 1.6131 - val_accuracy: 0.4493 - val_loss: 1.4202 - learning_rate: 2.7000e-06
# Epoch 15/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.4257 - loss: 1.5685
# Epoch 15: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.4269 - loss: 1.5666 - val_accuracy: 0.4458 - val_loss: 1.4437 - learning_rate: 1.0000e-06
# Epoch 16/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.4293 - loss: 1.5233
# Epoch 16: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4290 - loss: 1.5240 - val_accuracy: 0.4505 - val_loss: 1.4416 - learning_rate: 1.0000e-06
# Epoch 17/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.4640 - loss: 1.5420
# Epoch 17: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4635 - loss: 1.5422 - val_accuracy: 0.4752 - val_loss: 1.4300 - learning_rate: 1.0000e-06
# Epoch 18/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.4482 - loss: 1.5581
# Epoch 18: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4481 - loss: 1.5580 - val_accuracy: 0.5165 - val_loss: 1.4129 - learning_rate: 1.0000e-06
# Epoch 19/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.4174 - loss: 1.6349
# Epoch 19: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.4187 - loss: 1.6322 - val_accuracy: 0.5259 - val_loss: 1.4146 - learning_rate: 1.0000e-06
# Epoch 20/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.4435 - loss: 1.5601
# Epoch 20: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.4441 - loss: 1.5607 - val_accuracy: 0.5825 - val_loss: 1.3732 - learning_rate: 1.0000e-06
# Epoch 21/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.4380 - loss: 1.6131
# Epoch 21: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4381 - loss: 1.6134 - val_accuracy: 0.5920 - val_loss: 1.3693 - learning_rate: 1.0000e-06
# Epoch 22/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.4268 - loss: 1.6423
# Epoch 22: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.4265 - loss: 1.6414 - val_accuracy: 0.6274 - val_loss: 1.3357 - learning_rate: 1.0000e-06
# Epoch 23/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.4335 - loss: 1.6291
# Epoch 23: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4345 - loss: 1.6269 - val_accuracy: 0.6085 - val_loss: 1.3595 - learning_rate: 1.0000e-06
# Epoch 24/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.3808 - loss: 1.6307
# Epoch 24: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.3818 - loss: 1.6307 - val_accuracy: 0.6309 - val_loss: 1.3344 - learning_rate: 1.0000e-06
# Epoch 25/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.4238 - loss: 1.5764
# Epoch 25: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4231 - loss: 1.5785 - val_accuracy: 0.6156 - val_loss: 1.3693 - learning_rate: 1.0000e-06
# Epoch 26/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.4182 - loss: 1.6442
# Epoch 26: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4187 - loss: 1.6440 - val_accuracy: 0.6226 - val_loss: 1.3210 - learning_rate: 1.0000e-06
# Epoch 27/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.4173 - loss: 1.6002
# Epoch 27: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4175 - loss: 1.6013 - val_accuracy: 0.6450 - val_loss: 1.2924 - learning_rate: 1.0000e-06
# Epoch 28/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.4804 - loss: 1.4948
# Epoch 28: val_loss did not improve from 1.27968
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4793 - loss: 1.4965 - val_accuracy: 0.6108 - val_loss: 1.3225 - learning_rate: 1.0000e-06
# Epoch 29/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.4610 - loss: 1.6021
# Epoch 29: val_loss improved from 1.27968 to 1.26165, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.4601 - loss: 1.6020 - val_accuracy: 0.6356 - val_loss: 1.2617 - learning_rate: 1.0000e-06
# Epoch 30/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.4296 - loss: 1.6493
# Epoch 30: val_loss did not improve from 1.26165
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.4303 - loss: 1.6476 - val_accuracy: 0.6274 - val_loss: 1.2745 - learning_rate: 1.0000e-06
# Epoch 31/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.4598 - loss: 1.5683
# Epoch 31: val_loss did not improve from 1.26165
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4605 - loss: 1.5672 - val_accuracy: 0.6250 - val_loss: 1.2841 - learning_rate: 1.0000e-06
# Epoch 32/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step - accuracy: 0.4760 - loss: 1.5433
# Epoch 32: val_loss improved from 1.26165 to 1.25612, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.4753 - loss: 1.5448 - val_accuracy: 0.6745 - val_loss: 1.2561 - learning_rate: 1.0000e-06
# Epoch 33/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.4457 - loss: 1.6235
# Epoch 33: val_loss did not improve from 1.25612
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.4457 - loss: 1.6230 - val_accuracy: 0.6262 - val_loss: 1.3007 - learning_rate: 1.0000e-06
# Epoch 34/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - accuracy: 0.4458 - loss: 1.5645
# Epoch 34: val_loss did not improve from 1.25612
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4451 - loss: 1.5645 - val_accuracy: 0.6604 - val_loss: 1.2749 - learning_rate: 1.0000e-06
# Epoch 35/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.4272 - loss: 1.6011
# Epoch 35: val_loss did not improve from 1.25612
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4272 - loss: 1.6007 - val_accuracy: 0.6356 - val_loss: 1.3246 - learning_rate: 1.0000e-06
# Epoch 36/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.4357 - loss: 1.6691
# Epoch 36: val_loss did not improve from 1.25612
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4367 - loss: 1.6668 - val_accuracy: 0.6533 - val_loss: 1.2803 - learning_rate: 1.0000e-06
# Epoch 37/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.4302 - loss: 1.7035
# Epoch 37: val_loss did not improve from 1.25612
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4307 - loss: 1.7019 - val_accuracy: 0.6297 - val_loss: 1.2722 - learning_rate: 1.0000e-06
# Epoch 38/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.4291 - loss: 1.6340
# Epoch 38: val_loss did not improve from 1.25612
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.4293 - loss: 1.6330 - val_accuracy: 0.6450 - val_loss: 1.2657 - learning_rate: 1.0000e-06
# Epoch 39/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.4275 - loss: 1.5279
# Epoch 39: val_loss did not improve from 1.25612
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4275 - loss: 1.5296 - val_accuracy: 0.6498 - val_loss: 1.2619 - learning_rate: 1.0000e-06
# Epoch 40/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.4190 - loss: 1.5799
# Epoch 40: val_loss did not improve from 1.25612
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4192 - loss: 1.5803 - val_accuracy: 0.6179 - val_loss: 1.2963 - learning_rate: 1.0000e-06
# Epoch 41/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.4497 - loss: 1.5600
# Epoch 41: val_loss did not improve from 1.25612
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4494 - loss: 1.5604 - val_accuracy: 0.6533 - val_loss: 1.2896 - learning_rate: 1.0000e-06
# Epoch 42/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.4095 - loss: 1.6493
# Epoch 42: val_loss improved from 1.25612 to 1.24577, saving model to /content/drive/MyDrive/best_resnet152_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.4096 - loss: 1.6483 - val_accuracy: 0.6604 - val_loss: 1.2458 - learning_rate: 1.0000e-06
# Epoch 43/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.4376 - loss: 1.5265
# Epoch 43: val_loss did not improve from 1.24577
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.4371 - loss: 1.5275 - val_accuracy: 0.6274 - val_loss: 1.3278 - learning_rate: 1.0000e-06
# Epoch 44/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.4719 - loss: 1.5217
# Epoch 44: val_loss did not improve from 1.24577
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.4708 - loss: 1.5240 - val_accuracy: 0.6415 - val_loss: 1.2811 - learning_rate: 1.0000e-06
# Epoch 45/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step - accuracy: 0.4141 - loss: 1.6514
# Epoch 45: val_loss did not improve from 1.24577
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4143 - loss: 1.6513 - val_accuracy: 0.6403 - val_loss: 1.2706 - learning_rate: 1.0000e-06
# Epoch 46/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.4211 - loss: 1.6327
# Epoch 46: val_loss did not improve from 1.24577
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4205 - loss: 1.6337 - val_accuracy: 0.6533 - val_loss: 1.2939 - learning_rate: 1.0000e-06
# Epoch 47/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.4508 - loss: 1.5890
# Epoch 47: val_loss did not improve from 1.24577
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.4495 - loss: 1.5898 - val_accuracy: 0.6356 - val_loss: 1.2513 - learning_rate: 1.0000e-06
# Epoch 48/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step - accuracy: 0.4549 - loss: 1.5371
# Epoch 48: val_loss did not improve from 1.24577
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4543 - loss: 1.5383 - val_accuracy: 0.6415 - val_loss: 1.2916 - learning_rate: 1.0000e-06
# Epoch 49/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.4631 - loss: 1.6018
# Epoch 49: val_loss did not improve from 1.24577
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.4620 - loss: 1.6028 - val_accuracy: 0.6474 - val_loss: 1.2599 - learning_rate: 1.0000e-06
# Epoch 50/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.4154 - loss: 1.6364
# Epoch 50: val_loss did not improve from 1.24577
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4156 - loss: 1.6351 - val_accuracy: 0.6321 - val_loss: 1.2855 - learning_rate: 1.0000e-06
# Epoch 51/51
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.5001 - loss: 1.4989
# Epoch 51: val_loss did not improve from 1.24577
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 0.4994 - loss: 1.5007 - val_accuracy: 0.6368 - val_loss: 1.2678 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt
import os

graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# Accuracy
plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(); plt.title("Accuracy over Epochs")
plt.savefig(f"{graph_dir}/accuracy_plot.png")
plt.show()

# Loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(); plt.title("Loss over Epochs")
plt.savefig(f"{graph_dir}/loss_plot.png")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras.models import load_model

# === Load the trained ResNet152 model ===
model_path = "/content/drive/MyDrive/best_resnet152_model.keras"
model = load_model(model_path)
print("✅ Model loaded from:", model_path)

# === Directory to save plots ===
graph_dir = "/content/drive/MyDrive/diabetic_eye_results"
os.makedirs(graph_dir, exist_ok=True)

# === Predict on validation data ===
val_data.reset()
pred_probs = model.predict(val_data, verbose=1)
y_pred = np.argmax(pred_probs, axis=1)
y_true = val_data.classes

# === Get class mapping ===
class_indices = val_data.class_indices
index_to_label = {v: k for k, v in class_indices.items()}
valid_labels = sorted(index_to_label.keys())
target_names = [index_to_label[i] for i in valid_labels]

# === Debug info ===
print("Unique y_true:", np.unique(y_true))
print("Unique y_pred:", np.unique(y_pred))
print("Valid labels:", valid_labels)
print("Target names:", target_names)

# === Optional: Check class prediction counts ===
print("\nPredicted sample count per class:")
pred_counter = collections.Counter(y_pred)
for label in valid_labels:
    print(f"{index_to_label[label]}: {pred_counter.get(label, 0)}")

# === Accuracy Score ===
accuracy = accuracy_score(y_true, y_pred)
print(f"\n✅ Overall Validation Accuracy: {accuracy * 100:.2f}%")

# === Confusion Matrix ===
cm = confusion_matrix(y_true, y_pred, labels=valid_labels)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=target_names, yticklabels=target_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.savefig(f"{graph_dir}/confusion_matrix.png")
plt.show()

# === Classification Report ===
print("\nClassification Report:\n")
print(classification_report(
    y_true,
    y_pred,
    labels=valid_labels,
    target_names=target_names,
    zero_division=0  # Prevents warnings when precision is undefined
))
# Out:
# ✅ Model loaded from: /content/drive/MyDrive/best_resnet152_model.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 33s 843ms/step
# Unique y_true: [0 1]
# Unique y_pred: [0 1 2 3 4]
# Valid labels: [0, 1]
# Target names: ['abnormal', 'normal']
#
# Predicted sample count per class:
# abnormal: 415
# normal: 365
#
# ✅ Overall Validation Accuracy: 64.86%
# Classification Report:
#
#               precision    recall  f1-score   support
#
#     abnormal       0.61      0.73      0.67       348
#       normal       0.81      0.59      0.68       500
#
#    micro avg       0.71      0.65      0.68       848
#    macro avg       0.71      0.66      0.68       848
# weighted avg       0.73      0.65      0.68       848

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import os

# ---------- Required Inputs ----------
# y_true: true labels (e.g., [0, 2, 1, 4, ...]), shape = (n_samples,)
# pred_probs: predicted probabilities, shape = (n_samples, n_classes)
# labels: class names (optional, replace with your own)
# graph_dir: directory where to save plot

n_classes = 5
labels = [f'Class {i}' for i in range(n_classes)]  # Replace with actual names if needed
graph_dir = "./plots"

# Ensure output directory exists
os.makedirs(graph_dir, exist_ok=True)

# Binarize true labels for ROC computation
y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))

# Dictionaries to store ROC metrics
fpr, tpr, roc_auc = {}, {}, {}
missing_classes = []

# Compute ROC for each class
for i in range(n_classes):
    if np.sum(y_true_bin[:, i]) == 0:
        print(f"⚠️ Skipping ROC curve for {labels[i]} — no positive samples in y_true.")
        missing_classes.append(labels[i])
        continue
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# ---------- Plot ROC Curves ----------
plt.figure(figsize=(10, 8))

for i in range(n_classes):
    if i in roc_auc:
        plt.plot(fpr[i], tpr[i], label=f'{labels[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', label='Chance')
plt.title('ROC Curve for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# Save and show plot
plot_path = os.path.join(graph_dir, "roc_curve.png")
plt.savefig(plot_path)
plt.show()

# ---------- Summary ----------
if missing_classes:
    print(f"\nSkipped ROC for classes with no positive samples: {', '.join(missing_classes)}")
print(f"✅ ROC curve saved to: {plot_path}")
# Out:
# ⚠️ Skipping ROC curve for Class 2 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 3 — no positive samples in y_true.
# ⚠️ Skipping ROC curve for Class 4 — no positive samples in y_true.
# Skipped ROC for classes with no positive samples: Class 2, Class 3, Class 4
# ✅ ROC curve saved to: ./plots/roc_curve.png

# %%
model.save("/content/drive/MyDrive/final_resnet152_model.keras")
